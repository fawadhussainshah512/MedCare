# %%
import numpy as np

# %%
import pandas as pd

# %%
from scipy.sparse import hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
# Loading dataset
meds = pd.read_csv("/content/Medicine_Details.csv")

# %%
meds.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# 1  Vomiting Nausea Diarrhea Mucocutaneous candidi...
# 2                     Nausea Abdominal pain Diarrhea
# 3  Nausea Vomiting Diarrhea Upset stomach Stomach...
# 4     Headache Diarrhea Gastrointestinal disturbance
#
#                                            Image URL  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...
#
#                            Manufacturer  Excellent Review %  Average Review %  \
# 0          Roche Products India Pvt Ltd                  22                56
# 1  Glaxo SmithKline Pharmaceuticals Ltd                  47                35
# 2           Alembic Pharmaceuticals Ltd                  39                40
# 3          Glenmark Pharmaceuticals Ltd                  24                41
# 4            Cadila Pharmaceuticals Ltd                  34                37
#
#    Poor Review %
# 0             22
# 1             18
# 2             21
# 3             35
# 4             29

# %%
meds.describe()
# Out:
#        Excellent Review %  Average Review %  Poor Review %
# count        11825.000000      11825.000000   11825.000000
# mean            38.516025         35.756364      25.727611
# std             25.225343         18.268134      23.991985
# min              0.000000          0.000000       0.000000
# 25%             22.000000         27.000000       0.000000
# 50%             34.000000         35.000000      22.000000
# 75%             51.000000         47.000000      35.000000
# max            100.000000         88.000000     100.000000

# %%
meds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11825 entries, 0 to 11824
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Medicine Name       11825 non-null  object
#  1   Composition         11825 non-null  object
#  2   Uses                11825 non-null  object
#  3   Side_effects        11825 non-null  object
#  4   Image URL           11825 non-null  object
#  5   Manufacturer        11825 non-null  object
#  6   Excellent Review %  11825 non-null  int64
#  7   Average Review %    11825 non-null  int64
#  8   Poor Review %       11825 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 831.6+ KB

# %%
meds.columns
# Out:
# Index(['Medicine Name', 'Composition', 'Uses', 'Side_effects', 'Image URL',
#        'Manufacturer', 'Excellent Review %', 'Average Review %',
#        'Poor Review %'],
#       dtype='object')

# %%
meds.isnull().sum()
# Out:
# Medicine Name         0
# Composition           0
# Uses                  0
# Side_effects          0
# Image URL             0
# Manufacturer          0
# Excellent Review %    0
# Average Review %      0
# Poor Review %         0
# dtype: int64

# %%
meds.duplicated().sum()
# Out:
# 84

# %%
clean_df = meds.drop_duplicates()

# %%
clean_df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# 1  Vomiting Nausea Diarrhea Mucocutaneous candidi...
# 2                     Nausea Abdominal pain Diarrhea
# 3  Nausea Vomiting Diarrhea Upset stomach Stomach...
# 4     Headache Diarrhea Gastrointestinal disturbance
#
#                                            Image URL  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...
#
#                            Manufacturer  Excellent Review %  Average Review %  \
# 0          Roche Products India Pvt Ltd                  22                56
# 1  Glaxo SmithKline Pharmaceuticals Ltd                  47                35
# 2           Alembic Pharmaceuticals Ltd                  39                40
# 3          Glenmark Pharmaceuticals Ltd                  24                41
# 4            Cadila Pharmaceuticals Ltd                  34                37
#
#    Poor Review %
# 0             22
# 1             18
# 2             21
# 3             35
# 4             29

# %%
meds['Composition'].value_counts()
# Out:
# Luliconazole (1% w/w)                                                                                   98
# Levocetirizine (5mg) + Montelukast (10mg)                                                               77
# Ketoconazole (2% w/w)                                                                                   66
# Domperidone (30mg) + Rabeprazole (20mg)                                                                 60
# Itraconazole (100mg)                                                                                    53
#                                                                                                         ..
# Sodium Picosulfate (3.33mg/5ml) + Liquid Paraffin (1.25ml/5ml) + Milk Of Magnesia (3.75ml/5ml)           1
# Ambroxol (60mg) + Phenylephrine (5mg) + Levocetirizine (5mg)                                             1
# Digoxin (0.25mg)                                                                                         1
# Sulphacetamide (20% w/v)                                                                                 1
# Chromium Picolinate (100mcg) + D-Chiro Inositol (13.8mg) + Myo-Inositol (550mg) + Vitamin D3 (200IU)     1
# Name: Composition, Length: 3358, dtype: int64

# %%
salts_name = list(meds['Composition'].value_counts().keys())[0:20]
count_of_meds_with_that_salt = list(meds['Composition'].value_counts())[0:20]

# %%
# Composition

from matplotlib import pyplot as plt

plt.figure(figsize=(20,5))
plt.bar(salts_name, count_of_meds_with_that_salt, color = 'b')
plt.grid(True)
plt.title('Count of Meds with same composition')
plt.xticks(rotation=90)
plt.xlabel('Salts Name')
plt.ylabel('Count Of Medicine')
plt.show()

# %%
meds['Manufacturer'].value_counts()
# Out:
# Sun Pharmaceutical Industries Ltd    820
# Intas Pharmaceuticals Ltd            654
# Cipla Ltd                            574
# Torrent Pharmaceuticals Ltd          445
# Lupin Ltd                            435
#                                     ...
# Universal NutriScience                 1
# Orison Pharma International            1
# Pacific Biotech                        1
# Misae Lifesciences Pvt Ltd             1
# Albia Biocare                          1
# Name: Manufacturer, Length: 759, dtype: int64

# %%
manu_name = list(meds['Manufacturer'].value_counts().keys())[0:30]
count_manufacture_name = list(meds['Manufacturer'].value_counts())[0:30]

# %%
# Manufacturer

plt.figure(figsize=(20,5))
plt.bar(manu_name, count_manufacture_name, color = 'r')
plt.grid(True)
plt.title('Count of Meds with same Manufacturer')
plt.xticks(rotation=90)
plt.xlabel('Salts Name')
plt.ylabel('Count Of Medicine')
plt.show()

# %%
composition_value_counts = clean_df['Composition'].value_counts()
composition_value_counts
# Out:
# Luliconazole (1% w/w)                                                                                   98
# Levocetirizine (5mg) + Montelukast (10mg)                                                               76
# Ketoconazole (2% w/w)                                                                                   61
# Domperidone (30mg) + Rabeprazole (20mg)                                                                 59
# Itraconazole (100mg)                                                                                    53
#                                                                                                         ..
# Digoxin (0.25mg)                                                                                         1
# Sulphacetamide (20% w/v)                                                                                 1
# Furosemide (10mg/ml)                                                                                     1
# Chloroquine (500mg)                                                                                      1
# Chromium Picolinate (100mcg) + D-Chiro Inositol (13.8mg) + Myo-Inositol (550mg) + Vitamin D3 (200IU)     1
# Name: Composition, Length: 3358, dtype: int64

# %%
composition_names = composition_value_counts.index.tolist()
salts_name = composition_names[:30]
salts_name
# Out:
# ['Luliconazole (1% w/w)',
#  'Levocetirizine (5mg) + Montelukast (10mg)',
#  'Ketoconazole (2% w/w)',
#  'Domperidone (30mg) + Rabeprazole (20mg)',
#  'Itraconazole (100mg)',
#  'Telmisartan (40mg)',
#  'Itraconazole (200mg)',
#  'Domperidone (30mg) + Pantoprazole (40mg)',
#  'Telmisartan (40mg) + Amlodipine (5mg)',
#  'Glimepiride (2mg) + Metformin (500mg)',
#  'Metformin (500mg)',
#  'Minoxidil (5% w/v)',
#  'Ketoconazole (2% w/v) + Zinc pyrithione (1% w/v)',
#  'Amoxycillin  (500mg) +  Clavulanic Acid (125mg)',
#  'Rabeprazole (20mg)',
#  'Levocetirizine (5mg)',
#  'Glimepiride (2mg) + Metformin (500mg) + Pioglitazone (15mg)',
#  'Teneligliptin (20mg)',
#  'Methylcobalamin (750mcg) + Pregabalin (75mg)',
#  'Carboxymethylcellulose (0.5% w/v)',
#  'Terbinafine (1% w/w)',
#  'Glimepiride (2mg) + Metformin (500mg) + Voglibose (0.2mg)',
#  'Pantoprazole (40mg)',
#  'Montelukast (10mg) + Fexofenadine (120mg)',
#  'Metformin (500mg) + Teneligliptin (20mg)',
#  'Telmisartan (40mg) + Hydrochlorothiazide (12.5mg)',
#  'Glimepiride (1mg) + Metformin (500mg)',
#  'Progesterone (Natural Micronized) (200mg)',
#  'Pregabalin (75mg) + Nortriptyline (10mg)',
#  'Aceclofenac (100mg) + Paracetamol (325mg)']

# %%
# Creating medicine score column for each medicine
#weight_excell = 5.0
#weight_avg = 3.0
#weight_poor = 1.0
# using this formula we are calculating medicine_score
# score = (excell_improvement/100 * weight_excell) + (avg_improvement/100 * weight_avg) + (poor_improvement/100 * weight_poor)

meds['Medicine Score'] = round((meds['Excellent Review %']/100 * 5.0) + (meds['Average Review %']/100 * 3.0) + (meds['Poor Review %']/100 *1.0), 2)

# %%
meds['Medicine Score'].value_counts()
# Out:
# 4.34    910
# 3.00    697
# 5.00    610
# 3.66    489
# 1.66    421
#        ...
# 4.62      1
# 1.26      1
# 1.62      1
# 1.98      1
# 1.38      1
# Name: Medicine Score, Length: 166, dtype: int64

# %%
medicine_scores = list(meds['Medicine Score'].value_counts().keys())
count_medicine_score = list(meds['Medicine Score'].value_counts())

# %%
index = []
new_scores = []
for i in medicine_scores:
    if i>3.1:
        index.append(medicine_scores.index(i))
        new_scores.append(i)
    else :
        pass

# %%
scores_count = []
for i in index:
    scores_count.append(count_medicine_score[i])

# %%
import matplotlib.pyplot as plt

# Assuming 'salts_name' contains the top 30 composition names
# Replace 'salts_name' with your list of compositions

# Generate frequencies for each composition name
frequencies = [clean_df['Composition'].value_counts()[name] for name in salts_name]

# Create a bar plot with customizations
plt.figure(figsize=(10, 8))
plt.barh(salts_name, frequencies, color='skyblue', edgecolor='black')

plt.xlabel('Frequency')
plt.ylabel('Composition Names')
plt.title('Top 30 Composition Frequencies')
plt.gca().invert_yaxis()  # Invert y-axis to display the most frequent at the top

# Add frequency values as text on the bars
for i, v in enumerate(frequencies):
    plt.text(v + 0.2, i, str(v), color='black', va='center')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show plot
plt.show()

# %%
# Get the 10 value counts of side effects so we don't flood the notebook with too much stuff
side_effects_counts = clean_df['Side_effects'].value_counts()

# Create a dictionary to store medicines for each side effect
side_effects_medicines = {}

# Loop through unique side effects and collect associated medicines
for side_effect, count in side_effects_counts.items():
    # Filter DataFrame for each unique side effect
    medicines_for_side_effect = clean_df.loc[clean_df['Side_effects'] == side_effect, 'Medicine Name'].tolist()

    # Store the list of medicines for the side effect in the dictionary
    side_effects_medicines[side_effect] = medicines_for_side_effect

# Loop through the top 10 side effects and print their information
for idx, (side_effect, medicines) in enumerate(side_effects_medicines.items()):
    if idx >= 10:
        break  # Exit loop after printing 10 occurrences

    print(f"Side Effect: {side_effect}")
    print(f"Number of Occurrences: {side_effects_counts[side_effect]}")
    print(f"Medicines: {medicines}")
    print("------------------------")
# Out:
# Side Effect: Application site reactions burning irritation itching and redness
# Number of Occurrences: 389
# Medicines: ['Anovate Cream', 'Aziderm 20% Cream', 'Acivir Cream', 'Aziderm 10% Cream', 'Aziderm 10% Gel', 'Acivir Cream', 'Aziderm 20% Gel', 'AF-K Lotion', 'Aziderm 15% Gel', 'Acetik-HC Ear Drop', 'Atrodex-C Eye Drop', 'Afderm-MN + Cream', 'Ara Eye Drop', 'Azifast Gel', 'Amfy Gel', 'Adgaba Gel', 'Azobril Cream', 'Azobril Forte 20% Cream', 'AF-K Lotion', 'Allyzole Shampoo', 'Anti Druf Lotion', 'Amfy Gel', 'Afitra Cream', 'Betadine 10% Solution', 'Betadine 10% Ointment', 'Betadine 2% Gargle Mint', 'Betadine Powder', 'Betadine 2% Gargle Mint', 'Betadine Vaginal Pessaries', 'Bactafuz Cream', 'Betadine 5% Ointment', 'Betakind Gargle', 'Betadine 10% Solution', 'Betadine 5% Ointment', 'Bionect Ointment', 'Betadine 7.5% Surgical Scrub', 'Betadine Surgical Scrub 7.5% Solution', 'Biospor 1% Cream', 'Danclear  Shampoo', 'Diprolite Cream', 'Diprobate S Plus Ointment', 'Danclear  Cream', 'Dencross Scalp Lotion', 'Danblock Lotion', 'Drez Spray', 'Druffnil Shampoo', 'Drez 10% Solution', 'Dancure Shampoo', 'Dandrid Lotion', 'Dan Shine Lotion', 'Dufklin Lotion', 'Eumosone-M Cream', 'Elosone-HT Cream', 'Ebernet Cream', 'Ezanic 20% Cream', 'Eberfine Cream', 'Eyecon Eye Drop', 'Ebernet-M Cream', 'Elidel Cream', 'Ebernet Cream', 'Elosone-HT Cream', 'Ezanic 20% Gel', 'Entofoam Foam', 'Ezanic 10% Cream', 'Eberjen-M Cream', 'Ezhh Cream', 'Elvix Gel', 'Ebspor Cream', 'Ericlear Cream', 'Ebernet Lot', 'Eberfun Cream', 'Eberwin Cream', 'Eberclin Cream', 'Eberjen Cream', 'Ensarin-MF Cream', 'Efficort Cream', 'Ebernet Cream', 'Eberclin-M Cream', 'Ebermed 1% Cream', 'Etaze HT Cream', 'Ebercos Cream', 'Eveglow Cream', 'Ebermac Cream', 'Eberfine Cream', 'Eberderm Cream', 'Ezanic 10% Gel', 'Ebspor Cream', 'Eberwin Cream', 'Exapace Gel', 'Flusid Cream', 'Fusirose Lotion', 'Futop Cream', 'Fudic BNF Cream', 'Fusigen Spray', 'Fucidin Ointment', 'Fusigen-DP Cream', 'Flucort Forte Lotion', 'Fusinol Cream', 'Flucos Lotion', 'Flutivate 0.005% Ointment', 'FT-Mac Cream', 'Fusee Ointment', 'Fusiwal Cream', 'F Next Dusting Powder', 'Fusibest Cream', 'Fonafirst 1% Cream', 'Fusiwal B Cream', 'Fusiderm Ointment', 'Fuzinix Cream', 'Fusiscalp Lotion', 'Fusicare Cream', 'Fudic Cream', 'Forfora-Z Shampoo', 'Fulite Cream', 'Fusirose 2% Cream', 'Fusiwal Ointment', 'Fusee-B Cream', 'Fuderm Cream', 'Flucos ITZ Dusting Powder', 'Funzi-IT Dusting Powder', 'Gabagesic Gel', 'Gentalene Plus Cream', 'Gabapax L Gel', 'Gabacure Gel', 'Gapitas-L Gel', 'Gentalene Plus Cream', 'Gelofast Gel', 'Herpex 5% Cream', 'HHzole Cream', 'Halovate Cream', 'Herpikind Ointment', 'HHLite Cream', 'Hemolit Cream', 'Hypersol Ophthalmic Solution', 'Halox Cream', 'Halovate Ointment', 'Herperax Ointment', 'Halotop Cream', 'Halox Lotion', 'Halox Ointment', 'Halobet Cream', 'Halovate Lotion', 'Halotop Lotion', 'Haloderm Cream', 'Halonova Cream', 'Haloderm Cream', 'Habiccor Ointment', 'Habiccor Ointment', 'Halobet Cream', 'Hysoft Moisturizing Cream', 'Halonext 0.05% Lotion', 'Halomesh Cream', 'Hairshine Ktz Soap', 'ITR Plus Eye Drop', 'Intasporin Powder', 'Itral 1% Ointment', 'Infa  -VT Ointment', 'Itromed Gel', 'Itracoe Gel', 'Itaspor Powder', 'Intadine 5% Ointment', 'IZ K Lotion', 'Instaflex Nano Gel', 'Intadine Solution', 'Joyace Nano Gel 2X', 'Ketoscalp Shampoo from Leeford for Antifungal Infections', 'Ketostar Soap', 'Keralin Ointment', 'Ketostar Anti Dandruff Lotion', 'KZ Plus Lotion', 'Keto-B Lotion', 'Keto-AZ Lotion', 'Konaz -CT Lotion', 'Ktc Medicated Shampoo', 'Keto SZ Hair Wash', 'Ketonate Cream', 'Ktc Soap', 'Kenozole Shampoo', 'Ketafung CT Lotion', 'Ketonext CT Shampoo', 'Ketafung-Z Plus Lotion', 'Ketamide Soap', 'Kerashine-CT Anti-Dandruff Lotion', 'Kitnor Shampoo', 'Keto-B Lotion', 'Ketofast Shampoo', 'Ketar Scalp Solution', 'Kevon Zip Hair Conditioner', 'Kevon Zip Hair Conditioner', 'Ketol-Z Lotion', 'Ketofine-B Cream', 'Kozol ZP Shampoo', 'K2-Ziv Shampoo', 'Kozol Zpto Lotion', 'Ketoff Lotion', 'Ketofine Lotion', 'Kozol-B Cream', 'Klinique Forte  Anti-Dandruff Shampoo', 'Klinique Plus  Lotion', 'Kera ...
# ------------------------
# Side Effect: Hypoglycemia low blood glucose level Headache Nausea Diarrhea Flatulence
# Number of Occurrences: 173
# Medicines: ['Azulix 1 MF Tablet PR', 'Azulix 2 MF Tablet PR', 'Amaryl M Forte 2mg Tablet PR', 'Amaryl M Forte 1mg Tablet PR', 'Azulix 2 MF Forte Tablet PR', 'Azulix 3 MF Tablet PR', 'Azulix 1 MF Forte Tablet PR', 'Azulix 4 MF Tablet PR', 'Azulix 4 MF Forte Tablet PR', 'Azulix 0.5 MF Tablet PR', 'Blisto 2 MF Tablet PR', 'Diapride M2 Tablet PR', 'Diapride M 0.5mg/500mg Tablet PR', 'Duopil-HS 2/850 Tablet PR', 'Euglim-M 2 Tablet PR', 'Euglim-M 1 Tablet PR', 'Exermet GM 502 Tablet PR', 'Exermet GM 501 Tablet PR', 'Exermet GM Forte 2 Tablet PR', 'Easyaid 1 Tablet PR', 'Enristas 2MF Tablet PR', 'Exermet GM 0.5 Tablet SR', 'Glycomet-GP 1 Tablet PR', 'Glycomet-GP 2 Tablet PR', 'Glimestar-M 1 Tablet PR', 'Glycomet-GP 0.5 Tablet SR', 'Gluconorm-G 1 Tablet PR', 'Gluconorm G2 Tablet PR', 'Glycomet-GP 2 Forte Tablet SR', 'Gemer 0.5 Tablet PR', 'Glimestar-M 2 Tablet PR', 'Gemer DS 2 Tablet PR', 'Gluconorm G2 Forte Tablet PR', 'Glycomet-GP 1 Forte Tablet SR', 'Glycomet-GP 3/850 Tablet PR', 'Glimiprex MF 1/500 Tablet PR', 'Glimestar-M2 Forte Tablet PR', 'Glyciphage-G 1 Tablet PR', 'Gemer DS 1 Tablet PR', 'Geminor M 2 Tablet PR', 'Glimp-M 2 Tablet', 'Glimy M 1 Tablet PR', 'Glimp-M 1 Tablet', 'Glimiprex MF 2/500 Tablet PR', 'Glimisave M 2 Tablet PR', 'Glucoryl-M 2 Tablet PR', 'Gluconorm-G 1 Forte Tablet PR', 'Glycomet-GP 4 Forte Tablet PR', 'Gemer Forte 1 Tablet PR', 'Gemer Forte 2 Tablet PR', 'Glucoryl-M 1 Tablet PR', 'Glimisave M 1 Tablet PR', 'Glimestar-M1 Forte Tablet PR', 'Glimy M 2 Tablet PR', 'Geminor M2 Forte Tablet PR', 'Glyciphage-G 2 Tablet PR', 'Gemer DS 3 Tablet PR', 'Geminor M1 Forte Tablet PR', 'Gluconorm-G 0.5mg/500mg Tablet PR', 'Gluconorm-G 3 Forte Tablet PR', 'Gluconorm-G 4 Forte Tablet PR', 'Glimison-M 2 Tablet PR', 'Glimisave M2 Forte Tablet PR', 'Glycomet-GP 0.5 Forte Tablet PR', 'Glycomet-GP 1/850 Tablet PR', 'Gepride M1 Tablet PR', 'Glimiprex MF Forte 2 Tablet PR', 'Glador M1 Tablet PR', 'Glyciphage-G 2 Forte Tablet PR', 'Glador M2 Tablet PR', 'Gepride M2 Tablet PR', 'Gluformin G 2 New Tablet PR', 'Glycomet-GP 2/850 Tablet PR', 'Glucoryl-M 2 Forte Tablet PR', 'Glyciphage-G 1 Forte Tablet PR', 'Glimisave M 0.5 Tablet PR', 'Glimy M 2 Forte Tablet PR', 'Glimisave M1 Forte Tablet PR', 'Glyree-M 1 Tablet PR', 'Glimestar-M4 Forte Tablet PR', 'Glimestar-M 3 Tablet PR', 'Glisen MF 1 Tablet PR', 'Glucoryl-M 0.5 mg Tablet', 'Glitaray M 1  Tablet PR', 'Glimy M 0.5 Tablet PR', 'Glimestar M4 Tablet PR', 'Glimiprex MF Forte 1 Tablet PR', 'Glisen MF 2 Tablet PR', 'Geminor M 0.5 Tablet PR', 'Glyree-M 2 Tablet PR', 'Gepride M 0.5 Tablet PR', 'Gluconorm-G 3 Tablet PR', 'Gluconorm-G 0.5 Forte Tablet PR', 'Gluformin G 1 New Tablet PR', 'Glimisave M3 Forte Tablet PR', 'Gluconorm-G 4 Tablet PR', 'Glimisave M4 Forte Tablet PR', 'Geminor M 3 Forte Tablet PR', 'Glucoryl-M4 Forte Tablet PR', 'Glimaday 2 Tablet PR', 'Gepride M 3 Tablet PR', 'Glimulin-MF Tablet PR', 'Gepride M 1 Forte Tablet SR', 'GM -SR1 Tablet', 'Glimital-M1 Forte Tablet PR', 'Glimulin-2 MF Tablet PR', 'Glimisave M1 750 Tablet PR', 'Glynamic M 2mg/500mg Tablet', 'Glimser 1 Tablet PR', 'Glimison-M 2 Forte Tablet', 'Glimisave M2 750 Tablet PR', 'Gride-M Forte Tablet PR', 'Glucoryl-M 3 Forte Tablet PR', 'Glitaray M 2mg/500mg Tablet', 'Glisen MF Forte 1 Tablet', 'Gluconorm-G Plus 3 Tablet PR', 'Glimchek M 2mg/500mg Tablet', 'Glimaday-Forte 3 Tablet PR', 'Glimipack M 1mg/500mg Tablet', 'Gride-M 1mg/500mg Tablet', 'Glimisave Max 2 Tablet PR', 'Glador M4 Forte Tablet PR', 'Glimisave Max 1 Tablet PR', 'Glimisave Max Forte 2 Tablet PR', 'Glucut 1 MT Tablet', 'Glimulin MF Forte Tablet PR', 'Glimaday -HS Tablet PR', 'Glimisave Max Forte 1 Tablet PR', 'Glimser Forte 2 Tablet PR', 'Glimric-M3 Tablet SR', 'Glynova-M 2 Tablet SR', 'Glitaray M 1 Plus Tablet PR', 'GM SR2 Forte Tablet', 'Glupride-M2 Tablet SR', 'GM SR1 Forte Tablet', 'Genericart Glimepiride+Metformin Hydrochloride 4mg/1000mg Tablet PR', 'Isryl-M2 Tablet SR', 'Isryl-M1 Tablet SR', 'Isryl-M 4 Forte Tablet PR', 'ILet B 2 Tablet PR',  ...
# ------------------------
# Side Effect: No common side effects seen
# Number of Occurrences: 147
# Medicines: ['Aquasol A Capsule', 'Acton-OR Tablet SR', 'Anabel Liquid Gel', 'Anabel-CT Gel', 'Alfakit Tablet', 'Astymin-SN Infusion', 'Allenza Tablet', 'Alfa GPC Pastilles', 'Acnox Soap', 'Biosuganril 10 Tablet', 'Biovorin 15 Tablet', 'Bromin Tablet', 'Bromutrip Tablet', 'Dentogel Liquid', 'Dill-N Tablet', 'D3-Zen 60K Soft Gelatin Capsule', 'Dolanzen Tablet', 'D3K Softgel Capsule', 'Dentop-K Dental Gel', 'D-Gen 2K Softgel Capsule', 'Diflam Dental Gel', 'Evion LC Tablet', 'Eldervit 12 Combipack', 'Enzomac Tablet', 'Enzomac Forte Tablet', 'Enzoheal Tablet', 'Enzictra - DS Tablet', 'Emanzen Forte 10mg Tablet', 'Evaserve Tablet', 'Enzictra Tablet', 'Evanew Vaginal Tablet', 'Enzoheal Forte Tablet', 'Enzoflam SV  Tablet', 'Edinase  -DS Tablet', 'Espidase 10mg Tablet', 'Endocryl 0.5ml Injection', 'Edinase  Tablet', 'Enzrid-DS Tablet', 'Enzrid 90mg/48mg/100mg Tablet', 'Glutaup 500mg Tablet', 'Gee-X  Pain Relieving Gel', 'Hexilak Gel', 'Hexilak Gel', 'Hi-D3 60K Capsule', 'Hifenac Gel', 'Instaflex P Tablet SR', 'Ismigen Tablet', 'Kinetozyme Tablet', 'KLM-D3 Nano Drops', 'Kineto Forte Tablet', 'Ketodel Tablet', 'Klm Klin  Soap', 'Ksan Tablet', 'Lyser Forte Tablet', 'Lubrijoint 500 Tablet', 'Lubrijoint OD Tablet', 'Laretol Capsule', 'Liquid Parafin', 'Lidocam Mouth Wash', 'Leucorin Tablet', 'Lubrijoint 750 Tablet', 'Loy D3 Capsule', 'Lycomerve Capsule', 'Limcor Chewable Tablet Orange', 'Meganeuron OD Plus Capsule', 'M.V.I. Injection', 'Meaxon Plus Injection', 'Maxtra Gargle', 'Mucobenz Mouth Wash', 'Melaroc Tablet', 'Mucofresh Mouth Wash', 'Microshield 4% Surgical Handwash', 'Medsop Soap', 'Megacholin Pastilles', 'Multipro LC Soft Gelatin Capsule', 'Nurokind-Plus RF Capsule', 'Nurokind-Gold Injection', 'Nurokind-Plus NF Injection', 'Neosporin Dusting Powder', 'Nervijen Plus Injection', 'Newbona Fem Tablet', 'Neuromine-Plus Capsule', 'Nurostar C 0.7mg/1500mcg/12mg Injection', 'Nebazine Ointment', 'Orasep Gel', 'Ora-Fast Gel', 'Ovigyn D 3 Tablet SR', 'Otski Injection', 'Orahex Pro Mouth Wash Mint', 'Ovanac-DSR Tablet', 'Oraflora LA Gel', 'Orex Cream', 'Orogard SG Gel', 'Orex-LO Gel', 'Ovalink Tablet SR', 'Oralixir Mouth Wash', 'Oraeze Mouth Wash Mint', 'Phlogam Tablet', 'PA 12 Tablet SR', 'Paknet Soap', 'Qustain P 1000 Tablet SR', 'Rutoheal Tablet', 'Rejunuron Plus Injection', 'Rexite Plus 500 mcg/50 mg/50 mg Injection', 'Renoalfa Tablet', 'Ralgyz Soft Gelatin Capsule', 'Rutace-DS Tablet', 'Sitcom Tablet', 'Stelbid Tablet', 'Serowel Tablet', 'Stelbid 2 Tablet', 'SR Fil Enema', 'Solfe Tablet', 'Safeova Tablet', 'Skinn-C Soap', 'Silverstream Liquid', 'Seleno Gel', 'Sucral Povi Ointment', 'Serocit 46.7% Injection', 'Salitol Tablet', 'Silverstream Liquid', 'Tibrolin Tablet', 'Thromboscar Gel', 'Tantum Oral rinse', 'Thrize DS Tablet', 'Thrize Tablet', 'Tendolife Capsule', 'Tumsup Drop', 'Trexjoy Gel', 'Tolby-DS Soft Gelatin Capsule', 'Tantum Gel', 'Ultigel', 'Uvdyne Mouth Wash', 'Vitcofol Injection', 'Vitamin A Chewable Tablet', 'Vitcofol-C Combipack Injection', 'V D3 Sachet', 'Varenya Cream', 'Vaniza HC Gel', 'Vito Gold D3 Oral Solution', 'Writex-Gold Soft Gelatin Capsule', 'XTPara Proglet Tablet SR', 'Xtpara Tablet SR', 'Zymoflam Tablet', 'Zinase-XT Tablet', 'Zerostiff Sachet Orange Pineapple', 'Zuemeth Tablet']
# ------------------------
# Side Effect: Dizziness Sleepiness Tiredness Uncoordinated body movements
# Number of Occurrences: 123
# Medicines: ['Axogurd-SR Tablet', 'Axinerve-P Tablet SR', 'Axogurd  Capsule', 'Asmygaba-M Tablet', 'Benalgis Forte Soft Gelatin Capsule', 'Baga-M Capsule', 'Doloneuron 100 Tablet', 'Dubinor PM Capsule', 'Fine Nerve Soft Gelatin Capsule', 'Gabaneuron Tablet', 'Gabamax Gold Capsule', 'Gabapin ME Tablet', 'Gabantin Plus Tablet', 'Gabantin Forte Tablet', 'GB 29 1500mcg/75mg Tablet SR', 'Gabamax 75mg Capsule', 'Gabamax SR 75 Tablet', 'Gabapin Plus 100 Tablet', 'Gabanyl 300mg/500mcg Tablet', 'Gabawin 25 M Tablet', 'Gabaneuron SR 600 Tablet', 'Gaba-Hosit Tablet', 'Gabagesic M 300mg/500mcg Tablet', 'Gabafix-M SR Tablet', 'Gabafix-Plus Capsule', 'Gabaxia 75 SR Tablet', 'Gabastar-M Tablet', 'Gabacip M Tablet', 'Gabasafe Plus  SR 75 Tablet', 'Gabawin M 500mcg/75mg Tablet', 'Grantin Capsule', 'Gabawin 50M Tablet', 'Gabastar-M 300mg/500mcg Tablet', 'Mahagaba-M 75 Capsule', 'Meganeuron PG Capsule', 'Maxmala  50 Capsule', 'Maxmala  Capsule', 'Mahagaba-M OD Tablet SR', 'Maxmala Forte  Capsule', 'Maxgalin M 75 Capsule', 'Maxgalin M ER 75 Tablet', 'Maxgalin M 50 Capsule', 'ME-Pxl Tablet', 'Matilda PG  ER Tablet', 'ME-PR Capsule', 'Mymi Plus Capsule', 'Mecoblend-PSR Tablet', 'Myelogen PG 75 Tablet SR', 'Methypreg Tablet', 'Meganerv G 300mg/500mcg Tablet', 'Mecolab PG 750mcg/75mg Capsule', 'Maxgalin M 150 Capsule', 'Mecorik-G Tablet', 'Mnc Plus Capsule', 'Megabid 50 Capsule', 'Nurokind-G  Tablet', 'Nervijen-P Capsule', 'Nervmax SR 75 Tablet', 'Nurokind-G  100 New Tablet', 'Nervmax Capsule', 'Nervup PG Capsule', 'Neuractin-P 75 Capsule', 'Neurokem Plus Capsule', 'Neurica-M 75 Capsule', 'Neurokem-M Capsule', 'Nervz-G Tablet', 'Nevirin Tablet', 'Nova M 75 Capsule', 'Nervijen-P SR Tablet', 'Neuroprime-PG Capsule', 'Nervic-G Tablet', 'Nvm Dolo Tablet SR', 'Oxeogaba 750mcg/75mg Capsule', 'Pregaba-M 75 Capsule', 'Pregalin M 75 Capsule', 'Pregacip M Capsule', 'Pregator Capsule', 'Pregeb M 75 Capsule', 'Pregalin X SR 75 Tablet', 'Pregeb M OD 75 Tablet SR', 'Pregaba-M SR 75 Tablet', 'Pregalin M SR 75 Tablet', 'Pregabid ME 75 Capsule', 'Pevesca Plus Capsule', 'Pregason-M Capsule', 'Pregamet SR Tablet', 'Pregastar M 75 Capsule', 'Pbren-M 75 Capsule', 'Pregabel-M Capsule', 'Pregabid Forte 75 Capsule', 'Peg-SR M 75 Tablet', 'Pregabanyl Capsule', 'Pregamet 75 Capsule', 'Pregeb M 150 Capsule', 'Pregalin X 75 Capsule', 'Pregalin M 150 Capsule', 'Prelin M 75 Capsule', 'Pregeb M OD 150 Tablet', 'Pregastar M - OD 75 Tablet SR', 'Prelogic Capsule', 'Preega M 75 Capsule', 'Pregalin Forte Capsule', 'Pregalex-M Capsule', 'Pregabid M OD 100 Tablet SR', 'Pregadoc M - SR 75 Tablet', 'Progaba AM Tablet', 'Pregastar Plus SR 75 Tablet', 'Pregastar Plus SR 75 Tablet', 'Pedwin Tablet', 'Pregabid ME 150 Capsule', 'Pyrica-M  Capsule', 'Revlin M Tablet SR', 'Resner Tablet SR', 'Rugtrit 1500mcg/75mg Tablet', 'Renerve P 750mcg/75mg Capsule', 'Revlin M Capsule', 'Rejunuron DN Tablet SR', 'SR Pevesca Plus 75 Tablet', 'Supranerv-P Tablet SR', 'Trigabantin 100 Tablet', 'Trigabantin 300 Tablet', 'Trinogab-M Tablet', 'Vibanuron Tablet']
# ------------------------
# Side Effect: Application site reactions burning irritation itching and redness Dry skin Skin peeling Blisters on skin
# Number of Occurrences: 118
# Medicines: ['Afitra-L Cream', 'Emluz Cream', 'Fenza-L Cream', 'Funzi-L Lotion Alcohol Free', 'Funzi-L Cream', 'Fungerase-L Cream', 'Ibilul Cream', 'Lulifin Cream', 'Lulican Cream', 'Lulimac Cream', 'Lulibet Cream', 'Lulilok Cream', 'Lulizol Cream', 'L-Sys Cream', 'Luliderm Cream', 'L-Sys Lotion', 'Lulifin Lotion', 'Lulibrut Cream', 'Lulitec Cream', 'Ludura Cream', 'Lulican XL Cream', 'Lulifin Cream', 'Lulifin Cream', 'Lulibet Cream', 'Lilituf Cream', 'Luly Cream', 'Luray Cream', 'Lulican Forte 5% Lotion', 'LUCEE CREAM', 'Lulifin Cream', 'Luliderm Lotion', 'Lulimac Lotion', 'LzHH Cream', 'Luligee Cream', 'LT-Mac  Lotion', 'Lulibor Cream', 'Lucoz Cream', 'Lulibor Lotion', 'Lucrush Cream', 'Lumycan Cream', 'LT-Mac Cream', 'Luliact Cream', 'L-Sys Cream', 'Logifin CL 1% Lotion', 'Lilituf Cream', 'Lulimac XL Cream', 'Lulibet Lotion', 'Lulihalt Cream', 'L-Sys Cream', 'Lulizol Cream', 'Lofatin Cream', 'Luliz 1% Cream', 'Lulirx Cream', 'Luhon Cream', 'Lulimac Cream', 'Luray Cream', 'LzHH Lotion', 'Luligee Cream', 'Luliclinz-XL Cream', 'Luliderm Cream', 'Luliderm Cream', 'Lulifin Lotion', 'Lulisol Cream', 'Ludura Lotion', 'Luly Cream', 'Lucoz Cream', 'Lzhh-XL Cream', 'Lofatin Lotion', 'Lulizol Cream', 'Lucazole Cream', 'Lulilok Cream', 'Luliyes Cream', 'LUCEE CREAM', 'Luliford Cream', 'L-Trix Cream', 'Luliz 1% Cream', 'Lofatin Cream', 'Luliporus Cream', 'Leubine Cream', 'Lulirx Cream', 'Lilituf Cream', 'Lulimac XL Lotion', 'Lumycan Cream', 'Luliclin Cream', 'Lumycan Cream', 'LzHH Cream', 'Lulirx Spray', 'Lulibrut Lotion', 'Lulinext Cream', 'Luliclinz Cream', 'Lulibet Cream', 'Lulirx Spray', 'Lulinext Lotion Spray', 'Lulihalt Cream', 'Lulilok Soap', 'LT-Mac Cream', 'Ludura Cream', 'Lue 20 Cream', 'L-Sys Topical Solution', 'Lulibest 1% Cream', 'Lulipex 1% Cream', 'Lupizol Cream', 'Lilituf Lotion', 'Lulilok Cream', 'Lulipil Soap', 'Lofatin Cream', 'Lulibest-XL Cream', 'Luliyes Cream', 'Liconpride Cream', 'Lumiza 1% Cream', 'Lutriben Cream', 'L-Trix Cream', 'Lulijen Cream', 'Lucimac Cream', 'Orkid-L Cream', 'Zocon L Cream', 'Zocon L Cream', 'Zyluli 1% Cream']
# ------------------------
# Side Effect: Nausea Abdominal pain Constipation Dizziness Headache Indigestion Vomiting
# Number of Occurrences: 111
# Medicines: ['Alcros 100 Capsule', 'Alcros 200 Capsule', 'Apexitra 200 Capsule', 'Altispor 200 Capsule', 'Afitra 200 Capsule', 'Afitra 100 Capsule', 'Alitra 100 Capsule', 'Eukarit 100 Capsule', 'Fungikem 200 Capsule', 'Fungikem 100 Capsule', 'Funzi-IT 200 Capsule', 'Fungeeheal 200 Capsule', 'Funzi-IT 100mg Capsule', 'Fungikem 200 Capsule', 'Fungeeheal 100 Capsule', 'Fungikem 100 Capsule', 'Flucos ITZ 200 Capsule', 'Flucos ITZ 100 Capsule', 'Fungiquick Capsule', 'Glospor Capsule', 'Glospor-DS Capsule', 'Glospor Capsule', 'Glospor-DS Capsule', 'IT-Mac 100 Capsule', 'Itralase 100 Capsule', 'Itromed 200 Capsule', 'Itaspor 200 Capsule', 'Itaspor-SB Capsule', 'Itrasys 100 Capsule', 'Itrostred 200 Capsule', 'Itromed 100 Capsule', 'I-Win 100 Capsule', 'Itzhh 200 Capsule', 'Itradila 200 Capsule', 'I-Win 200 Capsule', 'Itrafix 200 Capsule', 'Itratuf Oral Solution', 'Itragreat 100 Capsule', 'Itrazole 100 Capsule', 'Itromed 200 Capsule', 'Itrason 200 Capsule', 'I-Tyza Capsule', 'Itragreat 200 Capsule', 'ITRAGEN 200MG CAPSULE', 'Itaspor Capsule', 'Itrasys CF 100 Capsule', 'Itzhh Capsule', 'Itraclar 100mg Capsule', 'Itracip 100 Capsule', 'Itragen 100 Capsule', 'Itratop 200mg Capsule', 'Itratuf Capsule', 'IT Mac 400mg Tablet SR', 'Itrasys 400 Capsule', 'Itralent 100mg Capsule', 'Itaphyte 200 Capsule', 'Itrabond 100 Capsule', 'Itralent 200 Capsule', 'Itrafix 100 Capsule', 'Itrafix 100 Capsule', 'Intrazole 200 Capsule', 'Itrabond 200 Capsule', 'Itracoe 200 Capsule', 'Itrazole 200 Capsule', 'Intrazole 100 Capsule', 'Itracip 200mg Capsule', 'Itraconol 200 Capsule', 'Itrostred 200 Capsule', 'Ibitra 100mg Capsule', 'Itra RD 200 Capsule', 'Itrastar 100mg Capsule', 'Itracat 200 Capsule', 'Iphytoral 100mg Capsule', 'Itrafung 100 Capsule', 'Ibitra 200mg Capsule', 'Itriben 100mg Tablet', 'Itranext Capsule', 'Itraderm DS Capsule', 'Itraclar 200 Capsule', 'Itrostred 100 Capsule', 'Itorate Capsule', 'Itracutis  100 Capsule', 'Itgo 50DT Tablet', 'Itriben 200 Capsule', 'Itracoe 400 SR Tablet', 'Itraderm Capsule', 'Itratuf Capsule', 'Itracyp 200mg Capsule', 'Itsbest 200 Capsule', 'Jimlig 100 Capsule', 'Kansel-IT 200 Capsule', 'Livafin O 200mg Capsule', 'Livafin -O 100 Capsule', 'Logispor 200 Capsule', 'Mycoclear 100 Capsule', 'Mitraa 200mg Capsule', 'Nixitral 100 Capsule', 'Nixitral 200 Capsule', 'Nokver 200 Capsule', 'Onitraz -Forte Capsule', 'Onitraz Capsule', 'Syntran 200 Capsule', 'Syntran Capsule', 'Sporanox Capsule', 'Syntran SB Capsule', 'Tinitraz 200 Capsule', 'Xerofung 200 Capsule', 'Xerofung 100 Capsule', 'Zitran 200 Capsule', 'Zole-IT 100 Capsule', 'Zole-IT 100 Capsule']
# ------------------------
# Side Effect: Limited data available
# Number of Occurrences: 98
# Medicines: ['Aquim PF Eye Drop', 'Amortas Cream', 'Aquaray Plus  Eye Drop', 'Amrobrut Cream', 'Amoron Cream', 'Amrobrut Cream', 'Amortas Cream', 'Amcrylate Bio-Adhesive', 'Aeocal Max Softgel Capsule', 'Amocop Cream', 'Bilagra M 20mg/10mg Tablet', 'Bilazest M Tablet', 'Bilacad M Tablet', 'Bisgram Tablet', 'Biofil-AB Particles', 'Billargic M Tablet', 'Belina Gel', 'Enzoflam-CT Tablet', 'Enzomac CM Particles', 'Eubri Eye Drop', 'Emrolfin Cream', 'Ecofab-HA Eye Drop', 'Fungicros Cream', 'Finetears Eye Drop', 'Forcutril Plus Cream', 'Gabafix Gel', 'Ginlac-V Vaginal Tablet', 'Gastrozin 75mg Tablet', 'Hadensa Ointment', 'Hylosoft Eye Drop', 'Hylosurge Eye Drop', 'Hyla PF Eye Drop', 'Hyvet  Eye Drop', 'Hyane Eye Drop', 'Hyla Fusion Eye Drop', 'Healtears Eye Drop', 'Hyla Eye Drop', 'Hyalgan Injection', 'Hyadry 0.1% Eye Drop', 'Hyal Oral Tablet', 'HY 5  Eye Drop', 'Hylu Fresh Eye Drop', 'Hadensa Ointment', 'Hymoist Eye Drop', 'Hylogel Gel', 'Hylo Grev Eye Drop', 'Hylowell Eye Drop', 'Hylumax Eye Drop', 'Hyaluron 200mg Tablet', 'I Soft Ophthalmic Solution', 'K-Trip Forte Tablet', 'Lubimoist Eye Drop', 'Lysoflam Forte 100000AU Tablet', 'Livopill -DS Tablet', 'Livopill Tablet', 'Livolexin Suspension', 'ME 12 OD Tablet ER', 'Montek BL Tablet', 'Moiz XL Cream', 'Meganano Gel', 'Maxigla Soft Gelatin Capsule', 'Misty Fresh Eye Drop', 'Monoguard Sertaconazole &amp; Zinc Pyrithione Shampoo | Fights Dandruff', 'Meganano Gel', 'Mibcal Soft Gelatin Capsule', 'Mycoclin Shampoo', 'Muscobon Tablet', 'Meganano Gel', 'Nuhenz Capsule', 'New Maxmoist Eye Drop', 'Nextane Ophthalmic Solution', 'New Alene Tablet', 'Nitrotap Applicap', 'Osmolube HY Eye Drop', 'Ocusoothe Duo Eye Drop', 'Osiris Tablet', 'Placentrex Injection', 'Placentrex Gel', 'Prulastin-M Tablet', 'Placentrex Cream', 'Resync Eye Drop', 'Romilast-BL Tablet', 'Rexnerve Plus Softgel Capsule', 'Soha 0.1% Eye Drop', 'Sistal Forte Tablet', 'Symhylo 1% Eye Drop', 'Soha 0.1% Eye Drop', 'Synvisc Hylan GF 20mg Injection', 'Senseit Gel', 'Silverkind Nanofine Gel', 'Soha Liquigel', 'Theo Tears 0.18% Eye Drop', 'Tricaine Alma Gel Mango Sugar Free', 'Uniwalk Capsule', 'Vasozine 0.05% Eye Drop', 'Xlha Eye Drop', 'Xymoheal Forte Tablet', 'Zyonate 14mg Injection']
# ------------------------
# Side Effect: Skin peeling Application site reactions burning irritation itching and redness Nausea Vomiting Abdominal pain Increased liver enzymes Application site redness Itching Diarrhea Abnormal liver function tests Adrenal insufficiency Application site burning
# Number of Occurrences: 90
# Medicines: ['Arcolane 2% Scalp Solution', 'Acvaketo Soap', 'Dersil-AF Body Wash', 'Denon Soap', 'Dany Cream', 'Esava Cream', 'Fungizole Cream', 'Fuket Soap', 'Iycotic Cream', 'IZ K Soap', 'Joyneca Anti fungal Soap', 'Ketostar Cream', 'Keto Cream', 'Ketofly Soap from Leeford for Skin Infections', 'K20 Soap', 'Kevon Lotion', 'Kevon Lotion', 'Kenozole Cream', 'Keto Soap', 'Konaz Antifungal Cream', 'Kenz Soap', 'Keto Gold Soap', 'KZ-XL Cream', 'Kenz Lotion', 'KZ Dusting Powder', 'K20 Cream', 'Keto Dusting Powder', 'K2-Zole Soap', 'K2-Zole Solution', 'Ketovate Cream', 'Ketafung Cream', 'Keto Cream', 'Keto Lotion', 'Ketafung Lotion', 'Kevon Cream', 'Ketzz 2% Cream', 'Ketobact Cream', 'Ketofine Cream', 'Ketofast Soap', 'Kozol Lotion', 'Ketonext AF Lotion', 'Kitnor Soap', 'Ktc 2% Cream', 'Ketonext Cream', 'Ketomed Plus Soap', 'Ketoliz 2% Cream', 'K Shine Lotion', 'Ketonext Soap', 'Ketox Cream', 'Ketogold Medicated Soap', 'Ketral  2% Scalp Solution', 'Ketoberg Soap', 'Ketofine Soap', 'Ketovate Soap', 'Ketotek Soap', 'Ketopan Soap', 'Ketzi Cream', 'Kozol Soap', 'K2-Zole LD Solution', 'Keyzol Cream', 'Ketodust Soap', 'Ketodust Cream', 'Ketoya 2% Cream', 'Ketonite Cream', 'Keyzol Soap', 'Kezop Soap', 'Myket Cream', 'Monokit Cream', 'Mesoketz Soap', 'Mesoketz Cream', 'Nizral 2% Solution', 'Nizral Cream', 'Novale Bar', 'Nizral Cream', 'Nizoclin-SX Lotion', 'Nizoclin Soap', 'Novale Scalp Lotion', 'Nozal Soap', 'Nizoclin Cream', 'Ocona  Soap', 'Phytoral Ointment', 'Phytoral Dusting Powder', 'Phytoral-XL Cream', 'Protek  Soap', 'PH-Bar', 'Salisia KT Soap', 'SGK Cream', 'Sebandro Soap', 'ZyKT Cream', 'ZyKT Cream']
# ------------------------
# Side Effect: Nausea Diarrhea Abdominal pain Hypoglycemia low blood glucose level
# Number of Occurrences: 86
# Medicines: ['Amaryl MV 2mg Tablet SR', 'Amaryl MV 1mg Tablet SR', 'Azulix MV 2/0.2 Tablet SR', 'Azulix MV 2mg/500mg/0.3mg Tablet SR', 'Azulix MV 1mg/500mg/0.3mg Tablet SR', 'Acmeglim-MV 2 Tablet SR', 'Azmet-VG 1 Tablet SR', 'Apriglim-MV 103 Tablet SR', 'Diapride M2 LV 2mg/500mg/0.2mg Tablet SR', 'Diapride M1 LV 1mg/500mg/0.2mg Tablet SR', 'Endoformin VG  2mg/500mg/0.2mg Tablet ER', 'Glycomet Trio 2 Tablet SR', 'Glycomet Trio 1 Tablet SR', 'Glimisave MV 3.3 Tablet SR', 'Glucoryl-MV 2 Tablet SR', 'Glycomet Trio 2/0.3 Tablet SR', 'Glycomet Trio Forte 2 Tablet SR', 'Glimisave MV 2 Tablet SR', 'Gluconorm-VG 2 Tablet SR', 'Glimda-MV 2 Tablet SR', 'Glyciphage-VG2 Tablet SR', 'Glycomet Trio 1/0.3 Tablet SR', 'Glucoryl-MV1 Tablet SR', 'Glimisave MV 1 Tablet SR', 'Glycomet Trio Forte 1 Tablet SR', 'Glimy M V2 Tablet SR', 'Glimisave MV2 Forte Tablet SR', 'Glucoryl-MV 2/0.3 Tablet SR', 'Gluconorm-VG 1 Tablet SR', 'Glimisave MV 3.3 F Tablet SR', 'Glyciphage-VG1 Tablet SR', 'Glynamic MV 2 Tablet', 'Glimisave MV 1.3 Tablet SR', 'Glyree MV 2 Tablet PR', 'Glimulin MV 2 Tablet ER', 'Gluconorm-VG 2 Forte Tablet SR', 'Glisen VM 2 Tablet SR', 'Glimulin MV 1 Tablet ER', 'Glisen VM 1 Tablet SR', 'Glorimet VG2 Tablet SR', 'Glimzen-MV2 Forte Tablet SR', 'Hmet Trio 2mg/500mg/0.3mg Tablet', 'Istaphase MG 2 Tablet PR', 'Jubiglim MV 2 Tablet SR', 'Laformin GV 2mg/500mg/0.2mg Tablet ER', 'Ozomet-VG2 Tablet SR', 'Ozomet-VG 1 Tablet SR', 'Switglim MV 2/0.3 Tablet ER', 'Starvog GM 1 Tablet SR', 'Trimegavog 2 Tablet SR', 'Trivoglitor 2 Tablet SR', 'Trivoglitor Forte 2 Tablet SR', 'Trivogo 2 Tablet SR', 'Trimegavog 1 Tablet SR', 'Trivoglitor 1 Tablet SR', 'Trivoglitor Forte 1 Tablet SR', 'T-Vobit VX2 Tablet SR', 'Trivoglicad 2 Tablet SR', 'Tribetrol 1 Tablet SR', 'Trimetaday V 2 Tablet SR', 'Trimetride 2 Tablet PR', 'Tribetrol 1 Forte Tablet SR', 'Trimetride 1 Tablet PR', 'Tripride 1 LV Tablet SR', 'Vogs-GM 2 Tablet SR', 'Voglimac GM 2 Tablet SR', 'Voglimet-GM Tablet SR', 'Volix Trio 2 Tablet ER', 'Voglinorm GM Forte 2 Tablet SR', 'Vogli-GM 2 Tablet', 'Vogliboz-GM2 Tablet', 'Vogs-GM 2/0.3 Tablet SR', 'Voglinorm-GM2 Tablet SR', 'Voglimac GM 1 Tablet SR', 'Voglibite-GM 2 Tablet SR', 'Vogli-GM 1 Tablet SR', 'Vogli-GM 2 Forte Tablet SR', 'Voglinorm GM 2/0.3 Tablet SR', 'Voglinorm-GM1 Tablet SR', 'Voglibite-GM 1 Tablet SR', 'Volix Trio Forte 1 Tablet ER', 'Vogloyd 3D 2.2 Tablet PR', 'Xmet-Trio 500/0.2/1 Tablet ER', 'Xilia-Trio 2 Tablet SR', 'Zoryl-MV 1 Tablet SR', 'Zoryl MV 2/0.3 Tablet SR']
# ------------------------
# Side Effect: Muscle pain Weakness Headache Abdominal pain Dizziness Joint pain Nausea
# Number of Occurrences: 80
# Medicines: ['Arvast 10 Tablet', 'Advastat 10 Tablet', 'Azuvas 10 Tablet', 'Arvast 40 Tablet', 'Arvast 5 Tablet', 'Arvast 15 Tablet', 'Arvast 30 Tablet', 'Gloristat 40 Tablet', 'Gloristat 10 Tablet', 'Jupiros 10 Tablet', 'Jubira 10 Tablet', 'Jupiros 20 Tablet', 'Jupiros 5 Tablet', 'Jubira 5 Tablet', 'Lipirose 10 Tablet', 'Lipitas 10 Tablet', 'Lipirose 20 Tablet', 'Lipigo 10 Tablet', 'Lipirose 5 Tablet', 'Lipitas 20 Tablet', 'Lipitas 40mg Tablet', 'Lipitas 5mg Tablet', 'Lipigo 5 Tablet', 'Novastat 10 Tablet', 'Novastat 5 Tablet', 'Rosuvas 10 Tablet', 'Rozavel 10 Tablet', 'Rosuvas 20 Tablet', 'Rosuvas 5 Tablet', 'Rozucor 10 Tablet', 'Rosuvas 40 Tablet', 'Rozavel 20 Tablet', 'Rosubest 10 Tablet', 'Rozavel 5 Tablet', 'Rosubest 20 Tablet', 'Rosulip 10 Tablet', 'Rozucor 20 Tablet', 'Rozavel 40 Tablet', 'Razel 10 Tablet', 'Rosuson 10 Tablet', 'Razel 40 Tablet', 'Roseday 40 Tablet', 'Rozucor 5 Tablet', 'Rosumac 20 Tablet', 'Rxtor 10 Tablet', 'Razel 20 Tablet', 'Rosukem 10 Tablet', 'Rosvin 10 Tablet', 'Rosulip 5 Tablet', 'Rovastat 10mg Tablet', 'Rosuson 40 Tablet', 'Rosuless 5 Tablet', 'Revostat 10 Tablet', 'Rosufit 5 Tablet', 'Rosukem 20 Tablet', 'Rosukem 5 Tablet', 'Rxtor 5 Tablet', 'Rosucrest 10 Tablet', 'Roslaren 20 Tablet', 'Rxtor 20 Tablet', 'Rosloy 20 Tablet', 'Rostar 20 Tablet', 'Rozutin 5 Tablet', 'Roliptin 10 Tablet', 'R2 10 Tablet', 'Roslaren 40 Tablet', 'Rozstyl 10 Tablet', 'Rosurica 20 Tablet', 'Rosta 10 Tablet', 'Rastrol 20 Tablet', 'Rovio 5 Tablet', 'Rozula 20mg Tablet', 'Rovio 20 Tablet', 'Rosbest 10 Tablet', 'Rosupack 20 Tablet', 'Statpure 20 Tablet', 'Statin R 20 Tablet', 'Zyrova 10 Tablet', 'Zyrova 20 Tablet', 'Zyrova 5 Tablet']
# ------------------------

# %%
# Get the value counts of uses
uses_counts = clean_df['Uses'].value_counts().head(10)

# Create a dictionary to store medicines for each use
uses_medicines = {}

# Loop through unique uses and collect associated medicines
for use, count in uses_counts.items():
    # Filter DataFrame for each unique use
    medicines_for_use = clean_df.loc[clean_df['Uses'] == use, 'Medicine Name'].tolist()

    # Store the list of medicines for the use in the dictionary
    uses_medicines[use] = medicines_for_use

# Display only the first 10 uses and their associated medicines
for idx, (use, medicines) in enumerate(uses_medicines.items()):
    if idx >= 10:
        break  # Exit loop after printing 10 occurrences

    print(f"Use: {use}")
    print(f"Number of Occurrences: {uses_counts[use]}")
    print(f"Medicines: {medicines}")
    print("------------------------")
# Out:
# Use: Treatment of Type 2 diabetes mellitus
# Number of Occurrences: 904
# Medicines: ['Amaryl 1mg Tablet', 'Ajaduo 25mg/5mg Tablet', 'Amaryl 2mg Tablet', 'Azulix 1 MF Tablet PR', 'Azulix 2 MF Tablet PR', 'Amaryl MV 2mg Tablet SR', 'Amaryl MV 1mg Tablet SR', 'Ajaduo 10mg/5mg Tablet', 'Amaryl M Forte 2mg Tablet PR', 'Amaryl M Forte 1mg Tablet PR', 'Azulix 1 Tablet', 'Azulix 2 MF Forte Tablet PR', 'Azulix 3 MF Tablet PR', 'Amaryl 3mg Tablet', 'Azulix 2 Tablet', 'Azulix 1 MF Forte Tablet PR', 'Aloja 25 Tablet', 'Azulix 4 MF Tablet PR', 'Azulix MV 2/0.2 Tablet SR', 'Azulix MV 2mg/500mg/0.3mg Tablet SR', 'Aim7 60 XR Tablet', 'Aplevant 0.75mg Pre-filled Pen', 'Azulix 4 MF Forte Tablet PR', 'Abvida 50mg Tablet', 'Azulix 0.5 MF Tablet PR', 'Azulix 3 Tablet', 'Azulix MV 1mg/500mg/0.3mg Tablet SR', 'Aloja 12.5 Tablet', 'Azulix 4 Tablet', 'Advog 0.3 Tablet', 'Acmeglim-MV 2 Tablet SR', 'Azukon Tablet', 'Advog 0.2 Tablet', 'Advog M 0.3 Plus Tablet', 'Abvida-M 50mg/1000mg Eazy Glide Tablet', 'Azmet-VG 1 Tablet SR', 'Apriglim-MV 103 Tablet SR', 'Adglim MP 2mg/500mg/15mg Tablet', 'Apriglim 2 Tablet', 'Anclazide-M Tablet', 'Bigomet SR 500 Tablet', 'Bigomet 500 Tablet', 'Blisto 2 MF Tablet PR', 'Biodib 15 Tablet', 'Bymet 500mg Tablet', 'Bigomet M  Tablet SR', 'Bigomet 850 Tablet', 'Bymet 1000 Tablet PR', 'Cyblex 60 XR Tablet', 'Diamicron MR 30 Tablet', 'Diapride M2 Tablet PR', 'Debistal-GM 2 Tablet ER', 'Duotrol Tablet', 'Diabetrol Tablet', 'Dianorm-OD 30 Tablet MR', 'Dianorm 80mg Tablet', 'Diabetrol SR Tablet', 'Diapride M2 LV 2mg/500mg/0.2mg Tablet SR', 'Diapride M 0.5mg/500mg Tablet PR', 'Dianorm-M OD Tablet SR', 'Diamet 500mg Tablet SR', 'Diapride M1 LV 1mg/500mg/0.2mg Tablet SR', 'Diabend -MR 60 Tablet', 'Dibeta GB 5 mg/500 mg Tablet', 'Diabend-MR 30 Tablet', 'Dianorm Total 30 Tablet SR', 'Diabend 40mg Tablet', 'Duotrol-SR Tablet', 'Dotzide M Tablet', 'Diabend-MEX 60 Tablet ER', 'Duopil-HS 2/850 Tablet PR', 'Dotzide 40mg Tablet', 'Eurepa 1 Tablet', 'Eurepa-V 1/0.3 Tablet', 'Exermet 500 SR Tablet', 'Euglim-M 2 Tablet PR', 'Eurepa MF 1 Tablet', 'Euglim 1 Tablet', 'Euglim-M 1 Tablet PR', 'Exermet GM 502 Tablet PR', 'Exermet GM 501 Tablet PR', 'Euclide M 30 OD Tablet ER', 'Eternex-T Tablet', 'Euglim 2 Tablet', 'Euclide M 60 OD Tablet ER', 'Eurepa-V 1/0.2 Tablet', 'Elcephase 500mg Tablet', 'Ecoglip-T Tablet', 'Eternex-M 500 Tablet SR', 'Exermet 1000 Tablet SR', 'Eurepa-V 0.5/0.3 Tablet', 'Exermet GM Forte 2 Tablet PR', 'Euclide 80 Tablet', 'Eternex-M 1000 Tablet SR', 'Eliptin M 500mg/20mg Tablet SR', 'Easyaid 1 Tablet PR', 'Efiglin-M 500mg/20mg Tablet ER', 'Enristas 2MF Tablet PR', 'Endoformin VG  2mg/500mg/0.2mg Tablet ER', 'Endoformin PG 2mg/500mg/15mg Tablet ER', 'Exermet GM 0.5 Tablet SR', 'Formin PG 2 Tablet SR', 'Formin Plus  500 Tablet SR', 'Formin Plus  1000 Tablet SR', 'Formin-SR 500 Tablet', 'Glycomet 500 SR Tablet', 'Glycomet-GP 1 Tablet PR', 'Glycomet-GP 2 Tablet PR', 'Glyciphage SR 500mg Tablet', 'Galvus Met 50mg/500mg Tablet', 'Glynase-MF Tablet', 'Glycomet Trio 2 Tablet SR', 'Glimestar-M 1 Tablet PR', 'Glizid-M Tablet', 'Glycomet-GP 0.5 Tablet SR', 'Glycomet Tablet', 'Gliptagreat M 500 Tablet', 'Gluconorm-G 1 Tablet PR', 'Glycomet 1gm Tablet SR', 'Gluconorm G2 Tablet PR', 'Glykind-M Tablet', 'Glycomet-GP 2 Forte Tablet SR', 'Gluconorm SR 500mg Tablet', 'Glimestar-PM2 Tablet ER', 'Glyxambi 25mg/5mg Tablet', 'Gemer 0.5 Tablet PR', 'Glucored Forte Tablet', 'Glimestar-M 2 Tablet PR', 'Galvus 50mg Tablet', 'Glycomet Trio 1 Tablet SR', 'Gibtulio 25mg Tablet', 'Gemer P 2 Tablet ER', 'Gemer DS 2 Tablet PR', 'Glucobay 50 Tablet', 'Gluconorm G2 Forte Tablet PR', 'Glynase Tablet', 'Glimisave MV 3.3 Tablet SR', 'Galvus Met 50mg/1000mg Tablet', 'GP 1 Tablet', 'Glycomet 250 Tablet', 'Glyciphage SR 1gm Tablet', 'Gluconorm PG 2  Tablet PR', 'Glycomet-GP 1 Forte Tablet SR', 'Glucoryl-MV 2 Tablet SR', 'Glycomet Trio 2/0.3 Tablet SR', 'Glyxambi 10mg/5mg Tablet', 'Glycomet-GP 3/850 Tablet PR', 'Gluxit 10mg Tablet', 'GP 2 Tablet', 'Glimiprex MF 1/500 Tablet PR', 'Glimestar-PM1 Tablet ER', 'GP 0.5 Tablet', 'Glimestar-M2 Fort ...
# ------------------------
# Use: Treatment of Bacterial infections
# Number of Occurrences: 434
# Medicines: ['Augmentin 625 Duo Tablet', 'Azithral 500 Tablet', 'Amoxyclav 625 Tablet', 'Azee 500 Tablet', 'Althrocin 500 Tablet', 'Azithral 200 Liquid', 'Azicip 500 Tablet', 'Almox 500 Capsule', 'Azee 200mg Dry Syrup', 'Augmentin 1000 Duo Tablet', 'Azee 250 Tablet', 'Azax 500 Tablet', 'Augmentin 1.2gm Injection', 'Augmentin 375 Tablet', 'Azikem 500mg Tablet', 'Apdrops PD Eye Drop', 'Azithral XL 200 Liquid', 'Althrocin 250 Tablet', 'Aziwok 500 Tablet', 'Azithral 100 Liquid', 'Azibact 500 Tablet', 'ATM 500 Tablet', 'Advent 625 Tablet', 'Acnesol Gel', 'Azee 100mg Dry Syrup Peppermint', 'Amoxyclav 375 Tablet', 'Almox 250 Capsule', 'Acuclav 625 Tablet', 'Azilide 500 Tablet', 'Alciflox 500mg Tablet', 'Augpen 625 BID Tablet', 'Azax 250 Tablet', 'Azee XL 200mg Dry Syrup Peppermint', 'Azibact LR 100 Readymix', 'Ampilox DS Tablet', 'Azimax 500 Tablet', 'Ampoxin 250 Capsule', 'Alevo 500 Tablet', 'Azifast 500 Tablet', 'Azivent 500 Tablet', 'Azibact 200 Readymix Oral Suspension', 'Altacef 500 Tablet', 'Azithral-XL 100 Liquid', 'ATM 200 Oral Suspension', 'ATM 100 Oral Suspension', 'Acnesol 1% solution', 'Aziwok 250 Tablet', 'Azibest 500mg Tablet', 'Ampilox CV 500 mg/125 mg Tablet', 'Amclaid 625 Tablet', 'Azee 250 Tablet', 'Azithral 500mg Injection', 'Aziwok-XL 200 Liquid', 'Azee 1000 Tablet', 'Azicip 250 Tablet', 'Altacef Suspension', 'Azibact 100 Readymix Oral Suspension', 'Azifast 250 Tablet', 'Ampoxin-CV 500mg/125mg Tablet', 'Azithral XL 200 Liquid', 'Altacef 250mg Tablet', 'Azee 100mg Tablet DT', 'Azee XL 100mg Dry Syrup Peppermint', 'Advent 1.2gm  Injection', 'Azimax 250 Tablet', 'Azithral KidTab', 'Ampoxin 1gm Injection', 'Augxetil CV 500 Tablet', 'ATM XL 100mg/5ml Syrup', 'Ampoxin 500mg Injection', 'Aziwin 500 Tablet', 'Azee 500 Tablet', 'Azimax 200 Dry Syrup', 'Azax 200 Suspension', 'Azilide -XL Redimed', 'Aziwok 600 Tablet', 'Aclind Gel', 'Aziclass 200mg Syrup', 'Alciflox 250mg Tablet', 'Azitus XL 100 Suspension', 'Alcipro 2mg/ml Infusion', 'Acnesol CL Gel', 'Anbid 500 Tablet', 'Azivent-XL 100mg Rediuse Oral Suspension', 'Azimax 500 Tablet', 'Acneclin Gel', 'Acuclav 1000mg Tablet', 'Acnecap Gel', 'Azam 200 Oral Suspension', 'Acv-LB Tablet', 'Aziquest 500mg Tablet', 'Acf 500 Tablet', 'Allyte Gel', 'Bactrim DS Tablet', 'Bactoclav 625 Tablet', 'Bactrim Syrup', 'Bactogard 200mg Tablet', 'Bicef 500 DT Tablet', 'Broadiclox Novo 500 mg Capsule', 'Biodoxi-LB Capsule', 'Bioclar 250mg Tablet', 'Blumox 250mg Tablet DT', 'Claribid 250 Tablet', 'Dalacin C 150mg Capsule', 'Doxcef 100mg Tablet DT', 'Dobact-Core Capsule', 'Distaclor Drop', 'Erytop Gel', 'Erytop Cream', 'Elores 1.5gm Injection', 'Erytop Lotion', 'Extacef 200 DT Tablet', 'Erythrocin 250mg Tablet', 'Erox CV 625 Tablet', 'Eltocin Tablet', 'Ecothral 500mg Tablet', 'Elores 3000mg Injection', 'Evoxil CV 500mg/125mg Tablet', 'Exeption 500 Tablet', 'Forcef 250mg Tablet', 'Forcef-CV 250 Tablet', 'Floxip 250 Tablet', 'Finecef 200mg Tablet DT', 'Gudcef 200 Tablet', 'Gramocef-O 200mg Tablet DT', 'Gudcef Dry Syrup', 'Glevo 500 Tablet', 'Gudcef -XL 200 New Tablet ER', 'Gudcef Drop', 'Gudcef 100mg Tablet DT', 'Genticyn 80mg Injection', 'Gramocef-CV Tablet', 'Gudcef XL Tablet', 'Glevo 750 Tablet', 'Goldclav 625 Tablet', 'Genorox 250mg Tablet', 'Grandcef 100 Oral Suspension', 'Greatcef 200 Tablet', 'Hhamclav 625 Tablet', 'HHCepo 200 Tablet', 'Hhazi 500 Tablet', 'Hhcefi 200 Tablet', 'HHCepo 100mg Dry Syrup', 'Indclav 625 Tablet', 'Ibithral 500mg Tablet', 'Joxcy 500mg Tablet', 'Jidox 200mg Tablet', 'Jifon 200 Tablet', 'Kefpod 200mg Tablet', 'Kefpod Suspension Orange', 'Klarim 250mg Tablet', 'Levoflox 500 Tablet', 'L-Cin 500 Tablet', 'Loxof 500mg Tablet', 'Levomac 500 Tablet', 'Leon 500 Tablet', 'Levoday 500 Tablet', 'Levoflox 750 Tablet', 'Levoflox 250 Tablet', 'Levoflox 500 Infusion', 'Lenteclin LB 100mg Capsule', 'L-Cin Syrup', 'L-Cin 750 Tablet', 'Labmox 250mg Capsule', 'Loxof 750mg Tablet', 'Leeford Clinsol Anti Acne Soap', 'L-Cin 250 Tablet', 'Levomac 750 Tablet', 'Laz 250mg Tablet', 'Levoquin 5 ...
# ------------------------
# Use:  Hypertension (high blood pressure)
# Number of Occurrences: 403
# Medicines: ['Amlosafe 3D Tablet', 'Arbitel-Trio 50 Tablet ER', 'Arbitel-Trio 25 Tablet ER', 'Amlokind-L Tablet', 'Amlokind-H Tablet', 'Amlong-H Tablet', 'Amlovas H  Tablet', 'Aten-D Tablet', 'Arbitel-CT 40 Tablet', 'Arkamin H Tablet', 'Asomex-TM Tablet', 'Ace Revelol 25/2.5 Tablet ER', 'Amlopres L Tablet', 'Amlodac-D Tablet SR', 'Amlopres Trio Tablet', 'Asomex-D Tablet', 'Amace Tablet', 'Amlodac CH Tablet', 'Arbitel-AMH Tablet', 'Amlosafe H Tablet', 'Amlovas-L Tablet', 'Ace Revelol 50/5 Tablet ER', 'Amodep-TMH Tablet', 'Asomex-LT Tablet', 'Atecard D Tablet', 'Amlace Tablet', 'Amtas-E Tablet', 'Amlosafe-LS 5/5 Tablet', 'Asar-CT 40/12.5 Tablet', 'Abel-CT 40mg/12.5mg Tablet', 'Alsartan AM Tablet', 'Angicam LT 50 mg/5 mg Tablet', 'Amtas HT Tablet', 'Asomex-AT 5 Tablet', 'Asomex-D 5 Tablet', 'Aten-H 12.5 Tablet', 'Amcard-LP Tablet', 'Aztric CT 12.5 Tablet', 'Angicam-H 5mg/12.5mg Tablet', 'Asomex-OH Tablet', 'Alphadopa 500 Tablet', 'Angizaar AT Tablet', 'Beta-Nicardia Capsule SR', 'Dilnip-Trio Tablet', 'Doxacard 2 Tablet', 'Eritel-CH 40 Tablet', 'Eritel-Trio Tablet', 'Espin-AT Tablet', 'Eritel-CH 80 Tablet', 'Embeta-R 2.5 Tablet', 'Embeta-R 5 Tablet ER', 'Eritel-CH 40 Trio Tablet', 'Enapril-HT Tablet', 'Espin TM  Tablet', 'Eslo Tan Tablet', 'Eritel-CH 80 Trio Tablet', 'Envas H Tablet', 'Enace D 10 Tablet', 'Espin H 2.5 mg/12.5 mg Tablet', 'Gloritel CT 40 Tablet', 'Genericart Amlodipine+Lisinopril 5mg/5mg Tablet', 'Hytrin 1 Tablet', 'Hytrin 2 Tablet', 'Hopace-MT 50 Tablet ER', 'Hopace-H 5 Capsule', 'Hipril A Tablet', 'Hopecard-H 5/12.5 Capsule', 'Irovel H Tablet', 'Inditel CH 40 Tablet', 'Inditel D Capsule SR', 'Inditel CH 80 Tablet', 'Inditel AH 40 Tablet', 'Lodoz 2.5 Tablet', 'Losar-A Tablet', 'Lodoz 5 Tablet', 'Lotensyl 10 Tablet', 'Losar-Beta Tablet', 'LTK-AM Tablet', 'Losar Beta-H Tablet', 'LN Met 50 Tablet ER', 'Loram  5 Tablet', 'Listril Plus Tablet', 'Losar-CH 12.5 Tablet', 'Losacar-A  Tablet', 'Lipril-H Tablet', 'Loram  2.5 Tablet', 'Lotak-A Tablet', 'Lipril AM Tablet', 'Lotensyl AT Tablet', 'Moxovas 0.3 Tablet', 'Moxovas 0.2 Tablet', 'Macsart CH 40 Tablet', 'Macsart CC  Tablet', 'Met XL R 25mg/2.5mg Tablet', 'Moxon 0.3 Tablet', 'Moxocard 0.3 Tablet', 'Metpure H Tablet', 'Moxon 0.2mg Tablet', 'Moxcent 0.3 Tablet', 'Myotan CT 40/12.5 Tablet', 'Met XL H 50 Tablet', 'Moxocard 0.2 Tablet', 'Metpure-H 50 Tablet', 'Macpril H 5 Tablet', 'Myotan CT 40/6.25 Tablet', 'Nebicard-SM Tablet', 'Nebicard T Tablet', 'Nebistar-SA Tablet', 'Natrilam 5 Tablet SR', 'Nebi-AM Tablet', 'Newtel-CH 40 Tablet', 'Nexovas O Tablet', 'Nebicard-H Tablet', 'Nulong-Trio Tablet', 'Nexovas M 50 Tablet', 'Nexovas O 40 Tablet', 'Nexovas Beta Tablet', 'Nexovas CH Tablet', 'Nebicard LN 5 Tablet', 'Nebi-H Tablet', 'Nulong-Trio 40 Tablet', 'Nebistar-H Tablet', 'Nebicard LN 2.5 Tablet', 'Nodon AM 5/5 Tablet', 'Nilol Tablet SR', 'Natrilam 2.5mg Tablet SR', 'Nebula-D Tablet SR', 'Nebicard-V Tablet', 'Nebilong H Tablet', 'Natrilam 10 Tablet SR', 'Nebula AM Tablet', 'Nulong-OL 20 Tablet', 'Nodon AM 2.5 mg/2.5 mg Tablet', 'Nodon H Tablet', 'Nubeta SM Tablet', 'Natcocil-M Tablet ER', 'Nulong-OL 40 Tablet', 'Numlo-TM 5 Tablet', 'Neopress AM 50mg/5mg Tablet', 'Nebipil SA Tablet', 'Nusar-AM 5 Tablet', 'Nebipil-H Tablet', 'Olmezest Beta 25 Tablet ER', 'Olmezest AM Tablet', 'Olmezest H 40 Tablet', 'Olmesar A Tablet', 'Olmezest Beta 50 Tablet ER', 'Olmezest AM 40 Tablet', 'Olmesar A 40 Tablet', 'Olmin Trio 40 Tablet', 'Olmesar H 40 Tablet', 'Olmesar  H Tablet', 'Olmezest CH 40 Tablet', 'Olkem Trio 40 Tablet', 'Olmin Trio Tablet', 'Olkem Trio 6.25 Tablet', 'Olmezest H 20 Tablet', 'Olmetime-AM 20 Tablet', 'Ozotel-AMH Tablet', 'Olmetime-AM 40 Tablet', 'Olkem Trio 12.5 Tablet', 'Olmetime-AMH 20 Tablet', 'Olmetime-H 40 Tablet', 'Olmezest CH 20 Tablet', 'Olmetime-AMH 40 Tablet', 'Olmat-H Tablet', 'Olmat 40 AMH Tablet', 'Olmat 20 AM Tablet', 'Olmetime-H 20 Tablet', 'Olmetime-CT 40 Tablet', 'Optidoz Tablet', 'Olmighty AM Tablet', 'Olkem 20 CT Tablet', 'Olmat 40 H Tablet', 'Olmighty 40H ...
# ------------------------
# Use:  Pain relief
# Number of Occurrences: 381
# Medicines: ['Altraday Capsule SR', 'Aldigesic-SP Tablet', 'Aceclo Plus Tablet', 'Acemiz Plus Tablet', 'Aldigesic P 100mg/325mg Tablet', 'Acenac-P  Tablet', 'Acemiz-S Tablet', 'Ace Proxyvon Tablet', 'Ace-Proxyvon CR Tablet', 'Aceclo Sera 100mg/325mg/15mg Tablet', 'Acceclowoc-P Tablet', 'Aceclo Tablet', 'Acimol Forte 100mg/325mg/15mg Tablet', 'Akilos-P Tablet', 'Acenext P 100mg/325mg Tablet', 'Acimol-SP Tablet', 'Aceclo SR Tablet', 'Arflur 3D Tablet', 'Aceloflam Plus Tablet', 'Arflur-P Tablet', 'Acenac Tablet', 'Acecloren Tablet', 'Alcinac P 100mg/325mg Tablet', 'Ark-AP Tablet', 'Aldigesic-Rab Capsule SR', 'Allenza Tablet', 'Actiheal-D Tablet', 'Acemiz 100mg Tablet', 'Aceron TC Tablet', 'Ace-Proxyvon SP Tablet', 'Aceloflam Plus Tablet', 'Adine-Plus Tablet', 'Acemiz 200 SR Tablet', 'Acendol-R Capsule SR', 'Anaflam XP 100mg/325mg Tablet', 'Aceloflam XP 100 mg/325 mg Tablet', 'Arflur CR  Tablet', 'Acenac SP 100mg/325mg/15mg Tablet', 'Acecloren P  Tablet 100mg/325mg', 'Acimol 200mg Tablet SR', 'Afenak Plus S 100mg/325mg/10mg Tablet', 'AC Para 100mg/325mg Tablet', 'Altraflam-P Tablet', 'Ark 100mg Tablet SR', 'Acelera-P Tablet', 'Ark 75mg Tablet', 'Arixib 90 Tablet', 'Ankon 90 Tablet', 'Asvoxia-P Tablet', 'Adcox-P Tablet', 'Almefkem 250mg Tablet', 'Brutaflam 90mg Tablet', 'Buta Proxyvon Capsule', 'Brutaflam-Plus Tablet', 'Bignac P Tablet', 'Bromin Tablet', 'Bromutrip Tablet', 'Chymoflam Tablet', 'Dicloran A Tablet', 'Drotikind 80mg Tablet', 'Diclotal 25mg Injection', 'Dolowin-SR Tablet', 'Dicloran SR Tablet', 'Dolonex Rapid 20mg Tablet', 'Droziver 80mg Tablet', 'Dill-N Tablet', 'Diclozyme-P Tablet', 'Dolonex Gel', 'Densaid-QA Sachet', 'Diasdac SP Tablet', 'Drotin DS Oral Suspension Mango Sugar Free', 'Diasdac-ER Tablet', 'Donica-SR Capsule', 'Dollos-P Tablet', 'Dolanzen Tablet', 'Diflam Dental Gel', 'Dolestin 250 Tablet', 'Enzoflam Tablet', 'Enzomac Plus Tablet', 'Emanzen-D Tablet', 'Enzomac Tablet', 'Etova-ER 600 Tablet', 'Enzomac Forte Tablet', 'Etoshine 60 Tablet', 'Etova 400 Tablet', 'Enzoheal Tablet', 'Etova-ER 400 Tablet ER', 'Ebility Tablet', 'Ezact 90 Tablet', 'Esgipyrin SP Tablet', 'Etos 90 Tablet', 'Etogesic ER Tablet', 'Etozox 90 Tablet', 'Etoshine 120 Tablet', 'Etody 90 Tablet', 'Etrik 90 Tablet', 'Esgipyrin-A Tablet', 'Etoxib 90 Tablet', 'Etrobax 90 Tablet', 'Enzictra Tablet', 'Etos P 60mg/325mg Tablet', 'Ezact 60 Tablet', 'Etrik P Tablet', 'Etowin 90 Tablet', 'Etocox 90 Tablet', 'Etoford 90 Tablet', 'Etosaid 90 Tablet', 'Etoro 90mg Tablet', 'Etogesic 400 Tablet', 'Etowin P 60mg/325mg Tablet', 'Esgipyrin 50mg/325mg Tablet', 'Etody 60 Tablet', 'Etos 60 Tablet', 'Enzoheal Forte Tablet', 'Etofree 600 ER Tablet', 'Etoford P 60 mg/325 mg Tablet', 'Enzoflam SV  Tablet', 'Etoford 120 Tablet', 'Enzosafe-D Tablet', 'Etova 200 Tablet', 'Etorica 120 Tablet', 'Etospeed 90 Tablet', 'Ezact 120 Tablet', 'ESGIPYRIN DS INJECTION', 'Etoxib 60 Tablet', 'Etody 120 Tablet', 'Etrobax 120 Tablet', 'Edinase-D  Tablet', 'Etowin 60mg Tablet', 'Edinase  -DS Tablet', 'Etorica 60 Tablet', 'Etoxib 120 Tablet', 'Etosaid 60 Tablet', 'Etorvel 90 Tablet', 'Ect 60 Tablet', 'Etosaid 120 Tablet', 'Etofine 90mg Capsule', 'Edinase  Tablet', 'Etorite Tablet PR', 'Ebov 90 Tablet', 'Espidase D Tablet', 'Etonow 90 Tablet', 'Etonow 120 Tablet', 'Enzrid-DS Tablet', 'Enzoloy H Tablet', 'Enzrid 90mg/48mg/100mg Tablet', 'Etrovis 90 Tablet', 'Etorvel 120mg Tablet', 'Enzowin-D  Tablet', 'Etogrand 90 Tablet', 'Etomav 90 Tablet', 'Etoroxi 120 Tablet', 'Etomav 120 Tablet', 'Feldex Tablet', 'Facer Sera Tablet', 'Flugesic SR Tablet', 'Flexilor 8 Tablet', 'Fensupp 12.5 Suppository', 'Fensupp 100 Suppository', 'Gelofast Gel', 'Hifenac-P Tablet', 'Hifenac Tablet', 'Hifenac-D  Tablet', 'Hifenac SR Tablet', 'Hifenac Gel', 'Indocap Capsule', 'Intacoxia 90 Tablet', 'Ibugesic ASP Tablet', 'Intacoxia 120 Tablet', 'Intacoxia 60mg Tablet', 'Imacin-SR 75 Capsule', 'Intacoxia P 60mg/325mg Tablet', 'Inmecin P 25mg/325mg Capsule', 'Inmecin 50mg Capsule', 'Inac 50 Tablet', 'Ibugesic AP  Tabl ...
# ------------------------
# Use: Treatment of Hypertension (high blood pressure)
# Number of Occurrences: 277
# Medicines: ['Arkamin Tablet', 'Amlopres-AT Tablet', 'Amlovas-AT Tablet', 'Amlopres TL Tablet', 'Amlip AT Tablet', 'Amlong-A Tablet', 'Angicam-Beta Tablet', 'Amlosafe TM 40 Tablet', 'Amtas-AT Tablet', 'Amtas-M 50 Tablet PR', 'Arbitel-AM Tablet', 'Amlopres AT 25 Tablet', 'Amlovas-M 5/50 Tablet PR', 'Aginal-AT Tablet', 'Amlong MT 50 Tablet PR', 'Arbitel-MT 50 Tablet ER', 'Asomex-AT Tablet', 'Amcard-AT Tablet', 'Amlopin-M Tablet PR', 'Arbitel-H Tablet', 'Amlodac AT Tablet', 'Aten AM Tablet', 'Arbitel-MT 25 Tablet ER', 'Amlosafe MT 50 Tablet PR', 'Amodep-TM Tablet', 'Amlokind-Beta 50 Tablet PR', 'Amtas-M 25 Tablet PR', 'Amlong-TL 40 Tablet', 'Amlong A-25 Tablet', 'Amlopin-AT Tablet', 'Amtas-AT 25 Tablet', 'Amlovas-AT 25 Tablet', 'Amloz AT Tablet', 'Amlodac T 40 mg/5 mg Tablet', 'Amlodac M Tablet PR', 'Arkapres 100 Tablet', 'Amlopin-M 5mg/25mg Tablet', 'Amlosafe TM 80 Tablet', 'Angicam-M Tablet PR', 'Asomex-TM 5 Tablet', 'Alsartan-H Tablet', 'Angizaar-H Tablet', 'Amloz AT 25 Tablet', 'Amlovas-M 2.5/25 Tablet PR', 'Arbitel-80 AM Tablet', 'Amlokem AT 5 mg/50 mg Tablet', 'Amlobet Tablet', 'Amdepin-AT Tablet', 'Atol AM Tablet', 'Amchek-AT Tablet', 'Amlokem M 5/50 Tablet', 'Atecard-AM Tablet', 'Biopress AM Tablet', 'Eritel LN 40 Tablet', 'Efnocar 40 Tablet', 'Eritel-AM Tablet', 'Embeta AM 50 Tablet PR', 'Efnocar 20 Tablet', 'Eslo-Tel 2.5mg Tablet', 'Eritel H Tablet', 'Eslo-AT Tablet', 'Embeta-TM 25 Tablet ER', 'Eslo-Tel 5mg Tablet', 'Eritel LN 80 Tablet', 'Efonta 40mg Tablet', 'Embeta AM 25 Tablet PR', 'Eritel B 40mg/50mg Tablet PR', 'Eritel B 40mg/25mg Tablet PR', 'Eslo-Met 2.5 Tablet', 'Eslo-5 AT Tablet', 'Esam-AT Tablet', 'Espin MT Tablet ER', 'Eritel 80-H Tablet', 'Gudpres-AM 50 Tablet PR', 'Giftan-HC Tablet', 'Gudpres-AM 25 Tablet PR', 'Gloritel M  40 Tablet', 'Gloritel AM  40 Tablet', 'Inditel AM Tablet', 'Inditel H 40 Tablet', 'Inditel MX 50 Tablet ER', 'Losar-H Tablet', 'Losakind-H Tablet', 'Lonitab 5 Tablet', 'LTK-H Tablet', 'Lostat-H Tablet', 'Losacar-H Tablet', 'Losium-H Tablet', 'Losanorm 50-H Tablet', 'Losatan H Tablet', 'Lonitab 10 Tablet', 'Losanorm 25-H Tablet', 'Lupidip-A Tablet', 'Metosartan 50 Tablet ER', 'Metosartan 25 Tablet ER', 'Macsart AM Tablet', 'Met XL AM 50/5 Tablet', 'Macsart H Tablet', 'Macsart Beta 50 Tablet ER', 'Metocard AM  Tablet PR', 'Metpure-AM 5  Tablet MR', 'Metolar AM  50 Tablet', 'Metpure-Tel 40 Tablet MR', 'Macsart Beta 25 Tablet ER', 'Metpure-AM 2.5 Tablet', 'Metolar TL 25 Tablet', 'Macsart CL 10mg/40mg Tablet', 'Mprol AM 5mg/50mg Tablet', 'Metolar TL 50 Tablet', 'Metolar AM  25 Tablet', 'Met Stamlo Capsule ER', 'Metopole-AM 5mg/50mg Tablet', 'Metozaar-A 50 Tablet', 'Metromax AM 5 mg/25 mg Tablet', 'Metonce-AM 50/5 Tablet', 'M Prol-AM Tablet ER', 'Nexovas T Tablet', 'Newtel-AM Tablet', 'Newtel-H 40 Tablet', 'Newtel-Beta 25 Tablet PR', 'Newtel-Beta 50 Tablet PR', 'Numlo-TM Tablet', 'Nusar-H Tablet', 'Ozotel-H Tablet', 'Ozotel-AM Tablet', 'Omnitan H Tablet', 'Prolomet AM 50 Tablet PR', 'Prolomet AM 25 Tablet PR', 'Primodil-AT  Tablet', 'Protol-AM Tablet PR', 'Protol 50 TL Tablet PR', 'Protol 25 TL Tablet PR', 'Repace H Tablet', 'Ranci T 10mg Tablet', 'Revas-H Tablet', 'Stamlo Beta Tablet', 'Stamlo-T Tablet', 'Sartel AM Tablet', 'Sartel-LN 40 Tablet', 'Sartel-Beta 50 Tablet ER', 'Sartel H 40 Tablet', 'Sartel-Beta 25 Tablet ER', 'Starpress-AM XL 50 Tablet', 'Samlokind-AT Tablet', 'Starpress T 25-XL Tablet', 'Starpress-AM XL 25 Tablet', 'Supermet-AM Tablet PR', 'Sartel AM 80 Tablet', 'Stamlo-T 80 Tablet', 'Starcad-T 50 Tablet ER', 'Telma H Tablet', 'Telma-AM Tablet', 'Telmikind-AM Tablet', 'Telmikind-H Tablet', 'Telvas H 40/12.5 Tablet', 'Tazloc-AM Tablet', 'Tazloc-Beta 25 Tablet PR', 'Tazloc-Beta 50 Tablet PR', 'Telma-LN 40 Tablet', 'Telvas Beta 50 Tablet ER', 'Telmikind Beta 50 Tablet ER', 'Telmikind Beta 40mg/25mg Tablet ER', 'Telma-Beta 25 Tablet ER', 'Telvas Beta 25 Tablet ER', 'Telma-Beta 50 Tablet ER', 'Tazloc-H Tablet', 'Telvas-LN 40 Tablet', 'Telma 80-H Tablet', 'Telplus Tablet', 'Telista CL ...
# ------------------------
# Use: Treatment of Fungal skin infections
# Number of Occurrences: 216
# Medicines: ['Abzorb Antifungal Soap', 'Abzorb Syndet Bar', 'Afitra Cream', 'Afitra-L Cream', 'Canazole Cream', 'Dermicee Cream', 'Ebernet Cream', 'Eberfine Cream', 'Ebernet-M Cream', 'Ebernet Cream', 'Eberjen-M Cream', 'Ezhh Cream', 'Ebspor Cream', 'Ericlear Cream', 'Ebernet Lot', 'Emluz Cream', 'Eberfun Cream', 'Eberwin Cream', 'Eberclin Cream', 'Eberjen Cream', 'Etaze-AF Lotion', 'Ebernet Cream', 'Eberclin-M Cream', 'Ebermed 1% Cream', 'Elmovel TF Gel', 'Etaze-AF Cream', 'Ebercos Cream', 'Ebermac Cream', 'Eberfine Cream', 'Eberderm Cream', 'Ebspor Cream', 'Eberwin Cream', 'Fungdid B Cream', 'Fenza-L Cream', 'Funzi-L Lotion Alcohol Free', 'F Next Dusting Powder', 'Funzi-L Cream', 'Funspor Dusting Powder', 'Fungerase-L Cream', 'Fungidust Dusting Powder', 'Fucross-B Solution', 'Flucos ITZ Dusting Powder', 'Funzi-IT Dusting Powder', 'Glocan Cream', 'HHzole Cream', 'Imidil Cream', 'Itral 1% Ointment', 'Imidil Dusting Powder', 'Itromed Gel', 'Itracoe Gel', 'Itaspor Powder', 'Ibilul Cream', 'Itgo-MT Cream', 'Keto-B Lotion', 'Kansel -DS Gel', 'Kansel-B Cream', 'Kansel -DS Lotion', 'Keto-B Lotion', 'Ketofine-B Cream', 'Kozol-B Cream', 'Lulifin Cream', 'Lulican Cream', 'Lulimac Cream', 'Lulibet Cream', 'Lulilok Cream', 'Lulizol Cream', 'L-Sys Cream', 'Luliderm Cream', 'L-Sys Lotion', 'Lulifin Lotion', 'Lulibrut Cream', 'Lulitec Cream', 'Ludura Cream', 'Lulican XL Cream', 'Lulifin Cream', 'Lulifin Cream', 'Lulibet Cream', 'Lilituf Cream', 'Luly Cream', 'Luray Cream', 'Lulican Forte 5% Lotion', 'LUCEE CREAM', 'Lulifin Cream', 'Luliderm Lotion', 'Lulimac Lotion', 'LzHH Cream', 'Luligee Cream', 'LT-Mac  Lotion', 'Lulibor Cream', 'Lucoz Cream', 'Lulibor Lotion', 'Lucrush Cream', 'Lumycan Cream', 'LT-Mac Cream', 'Luliact Cream', 'L-Sys Cream', 'Logifin CL 1% Lotion', 'Lamifin-M Cream', 'Lilituf Cream', 'Lulimac XL Cream', 'Lulibet Lotion', 'Lulihalt Cream', 'L-Sys Cream', 'Lulizol Cream', 'Lofatin Cream', 'Luliz 1% Cream', 'Lulirx Cream', 'Luhon Cream', 'Lulimac Cream', 'Luray Cream', 'LzHH Lotion', 'Luligee Cream', 'Luliclinz-XL Cream', 'Luliderm Cream', 'Luliderm Cream', 'Lulifin Lotion', 'Lulisol Cream', 'Ludura Lotion', 'Luly Cream', 'Lucoz Cream', 'Lzhh-XL Cream', 'Lofatin Lotion', 'Lulizol Cream', 'Lucazole Cream', 'Lulilok Cream', 'Luliyes Cream', 'LUCEE CREAM', 'Luliford Cream', 'L-Trix Cream', 'Luliz 1% Cream', 'Lofatin Cream', 'Luliporus Cream', 'Leubine Cream', 'Lulirx Cream', 'Lilituf Cream', 'Lulimac XL Lotion', 'Lumycan Cream', 'Luliclin Cream', 'Lumycan Cream', 'LzHH Cream', 'Lulirx Spray', 'Lulibrut Lotion', 'Lulinext Cream', 'Luliclinz Cream', 'Lulibet Cream', 'Lulirx Spray', 'Lulinext Lotion Spray', 'Lulihalt Cream', 'Lulilok Soap', 'LT-Mac Cream', 'Ludura Cream', 'Lue 20 Cream', 'L-Sys Topical Solution', 'Lulibest 1% Cream', 'Lulipex 1% Cream', 'Lupizol Cream', 'Lilituf Lotion', 'Lulilok Cream', 'Lulipil Soap', 'Lofatin Cream', 'Lulibest-XL Cream', 'Luliyes Cream', 'Liconpride Cream', 'Lumiza 1% Cream', 'Lutriben Cream', 'L-Trix Cream', 'Lulijen Cream', 'Lucimac Cream', 'Micogel Cream', 'Mycoderm-C Dusting Powder', 'Micogel F Ointment', 'Momoz T Cream', 'Momesone-T Cream', "Mankind's Ring-Out Dusting Powder", 'Micogel F Cream', 'Metacortil-C Cream', 'Metafine Cream', 'Mycocid Cream', 'Mycozole-F Cream', 'Nuforce Dusting Powder', 'Nuforce Soap', 'Onabet SD Solution', 'Orkid-L Cream', 'Propyzole NF Cream', 'Panderm + Dusting Powder', 'Phytoral B Cream', 'Rizole DS Cream', 'Rivizole Cream', 'Rivizole F Ointment', 'Rexizole 1% Cream', 'Surfaz Cream', 'Sebifin Plus Cream', 'Surfaz Dusting Powder', 'Scalnex CT Lotion', 'Surfaz Topical Solution', 'Triben B Cream', 'Triben- B Lotion', 'Tyza M Gel', 'Terbinaforce-M Cream', 'Triben CN Cream', 'Triben Lotion', 'Triben Dusting Powder', 'Terbicort Cream', 'Terbiskin-M Cream', 'Triben Dusting Powder', 'Zole-F Ointment', 'Zydip-C Lotion', 'Zocon 1% Dusting Powder', 'Zole Skin Ointment', 'Zydip-C Cream', 'Zocon L Cream', 'Zole-F Lotion', 'Zocon 1% Soap', 'Zocon -C Cream', 'Zocon L Cream' ...
# ------------------------
# Use: Treatment of Neuropathic pain
# Number of Occurrences: 185
# Medicines: ['Axogurd-SR Tablet', 'Axogurd NT Tablet SR', 'Axinerve-P Tablet SR', 'Axogurd  Capsule', 'Arigaba NT 100 Tablet', 'Arigaba NT Tablet', 'Axinerve-NP Tablet', 'Adnurve SR Tablet', 'Acenac-N Tablet PR', 'Asmygaba-NT Tablet', 'Asmygaba-M Tablet', 'Benalgis Forte Soft Gelatin Capsule', 'Baga-M Capsule', 'Doloneuron NT Tablet', 'Doloneuron 100 Tablet', 'Diomilin-NT Tablet', 'Dubinac-SR Tablet', 'Fibrogesic N Tablet', 'Gabapin NT Tablet', 'Gabapin NT 100 Tablet', 'Gabaneuron NT Tablet', 'Gabaneuron Tablet', 'GB 29 Total Tablet', 'Gabantin-NT Tablet', 'Gabamax Gold Capsule', 'Gabapin ME Tablet', 'Gabamax NT Tablet', 'Gabanyl NT 400mg/10mg Tablet', 'Gabantin Plus Tablet', 'Gabator NT 400mg/10mg Tablet', 'Gabantin Forte Tablet', 'Gabaneuron NT 400 Tablet', 'GB 29 1500mcg/75mg Tablet SR', 'Gabafix NT 75mg/10mg/1500mcg Tablet', 'GB 29 Plus Tablet', 'Gabamax 75mg Capsule', 'Gabamax SR 75 Tablet', 'Gabamax NT 50mg/10mg Tablet', 'Gabanyl 300mg/500mcg Tablet', 'Gabawin 25 M Tablet', 'Gabaneuron SR 600 Tablet', 'Gaba-Hosit Tablet', 'Gabagesic M 300mg/500mcg Tablet', 'Gabafix-M SR Tablet', 'Gabalent-NT Tablet', 'Gabaloy-NT Tablet', 'Gabadon-NTP 400mg/10mg Tablet', 'Gabawok-NT 100 Tablet', 'Gabanyt 400mg/10mg Tablet', 'Gabawell NT  400mg/10mg Tablet', 'Gabastar-M Tablet', 'Gabacip M Tablet', 'Gabasafe Plus  SR 75 Tablet', 'Gabacnx NT 400mg/10mg Tablet', 'Gabacnx NT 100 Tablet', 'Gabawin M 500mcg/75mg Tablet', 'Grantin Capsule', 'Gabawin 50M Tablet', 'Gabastar-M 300mg/500mcg Tablet', 'Gabanev-NT 400mg/10mg Tablet', 'Laregab NT 400mg/10mg Tablet', 'Mahagaba-M 75 Capsule', 'Meganeuron PG Capsule', 'Meganeuron NT 75 Tablet', 'Meganeuron NT 50 Tablet', 'Maxgalin NT Tablet', 'Mahagaba-M OD Tablet SR', 'Maxgalin M 75 Capsule', 'Maxgalin M ER 75 Tablet', 'Maxgalin M 50 Capsule', 'ME-Pxl Tablet', 'Matilda PG  ER Tablet', 'ME-PR Capsule', 'Mymi Plus Capsule', 'Mecoblend-PSR Tablet', 'Mecobion-NP Tablet SR', 'Methypreg Tablet', 'Meganerv G 300mg/500mcg Tablet', 'Mecolab PG 750mcg/75mg Capsule', 'Maxgalin M 150 Capsule', 'Mecorik-G Tablet', 'Mnc Plus Capsule', 'Megabid 50 Capsule', 'Nurokind-G  Tablet', 'Nortipan-M Tablet SR', 'Nervijen-P Capsule', 'Nervmax SR 75 Tablet', 'Nervijen-NP Tablet', 'Nervite Plus Tablet', 'Nurokind-G  100 New Tablet', 'Nurogab NT  Tablet', 'Nortipan Tablet', 'Nervmax Capsule', 'Nervmax NT 75mg/10mg Tablet', 'Nervite Tablet', 'Nortryptomer-P 10mg/75mg Tablet', 'Neurica NT Tablet', 'Neuractin-P 75 Capsule', 'Nortipan 50mg/10mg Tablet', 'Neurobid-NT Tablet SR', 'Neurica-M 75 Capsule', 'Nervotop Tablet SR', 'Neurokem-M Capsule', 'Nortryptomer-P SR 50 Tablet', 'Nervz NT Tablet SR', 'Nervz-G Tablet', 'Nova M 75 Capsule', 'Nervijen-P SR Tablet', 'Neuroprime-PG Capsule', 'Nervic-G Tablet', 'Nvm Dolo Tablet SR', 'Oxeogaba 750mcg/75mg Capsule', 'Pregaba-M 75 Capsule', 'Pregaba NT 75 mg/10 mg Tablet', 'Pregabid NT Tablet', 'Pregalin M 75 Capsule', 'Pregacip M Capsule', 'Pregabanyl NTM Tablet', 'Pentanerv-NT Tablet', 'Pregalin NT 75mg/10mg Tablet', 'Pregeb M 75 Capsule', 'Pregabid MNT Tablet', 'Pregabanyl NT Tablet', 'Pregalin X SR 75 Tablet', 'Pregeb M OD 75 Tablet SR', 'Pregaba-M SR 75 Tablet', 'Pregadoc  NT 75mg/10mg Tablet', 'Pbren NT 75mg/10mg Tablet', 'Pregalin M SR 75 Tablet', 'Pentanerv-NT 100mg/10mg Tablet', 'Pregabid ME 75 Capsule', 'Pregabid NT 50mg/10mg Tablet', 'Pregason-M Capsule', 'Peg-NT Tablet', 'Pregamet SR Tablet', 'Pregastar M 75 Capsule', 'Pregalift NT Tablet', 'Pbren-M 75 Capsule', 'Pregabel-M Capsule', 'Peg-SR M 75 Tablet', 'Pregabanyl Capsule', 'Pregalex-NT Tablet', 'Pregamet 75 Capsule', 'Pregathree Tablet', 'Pregeb M 150 Capsule', 'Pregalin X 75 Capsule', 'Preganza NT Tablet', 'Pregalin M 150 Capsule', 'Prelin M 75 Capsule', 'Pregeb M OD 150 Tablet', 'Pregastar M - OD 75 Tablet SR', 'Prelogic Capsule', 'Preega M 75 Capsule', 'Prenura NT Tablet', 'Pregalex-M Capsule', 'Pregabid M OD 100 Tablet SR', 'Pyrope NTM Tablet SR', 'Pregadoc M - SR 75 Tablet', 'Progaba AM Tablet', 'Pyrope NT  75mg/10mg Tablet', 'Pe ...
# ------------------------
# Use: Treatment of Fungal infections
# Number of Occurrences: 179
# Medicines: ['AF 400 Tablet', 'AF 150 Tablet DT', 'AF 200 Tablet', 'Alcros 100 Capsule', 'Alcros 200 Capsule', 'AF 300 Tablet', 'AF 50 Tablet DT', 'Amortas Cream', 'Amrobrut Cream', 'Amoron Cream', 'Amrobrut Cream', 'Apexitra 200 Capsule', 'Amortas Cream', 'Altispor 200 Capsule', 'Afitra 200 Capsule', 'Amocop Cream', 'Afitra 100 Capsule', 'Azolbest-KT Shampoo', 'Alitra 100 Capsule', 'Danket Shampoo', 'Denon Shampoo', 'Exizol Shampoo', 'Eukarit 100 Capsule', 'Emrolfin Cream', 'Fungicip 200 Tablet', 'Fungikem 200 Capsule', 'Forcan 200mg Infusion', 'Flucos 400mg Tablet', 'Fungikem 100 Capsule', 'Flumet 150mg Tablet', 'FCN 200mg Tablet', 'Funzi-IT 200 Capsule', 'Flucos 200 Tablet', 'Flumet 200mg Tablet', 'Fusys DT Tablet', 'Fungicros Cream', 'Forcan 50 Tablet', 'Fungeeheal 200 Capsule', 'Fungiset 150mg Tablet', 'Fenazol 150 Tablet', 'FZHH Tablet', 'Funzi-IT 100mg Capsule', 'Flutas 400mg Tablet', 'Flucos DT 50 Tablet', 'Fungikem 200 Capsule', 'Fungeeheal 100 Capsule', 'Flutas 150 Tablet', 'Fungid Best 150mg Tablet', 'Fungikem 100 Capsule', 'Fungicip 150mg Tablet', 'Flucos ITZ 200 Capsule', 'Fluzol 150mg Tablet', 'Flucos ITZ 100 Capsule', 'Flucalup 50mg Tablet', 'Flucowin Tablet', 'Fungiquick Capsule', 'Glospor Capsule', 'Glospor-DS Capsule', 'Gocan 150mg Tablet', 'Glospor Capsule', 'Glospor-DS Capsule', 'IT-Mac 100 Capsule', 'Itralase 100 Capsule', 'Itromed 200 Capsule', 'Itaspor 200 Capsule', 'Itaspor-SB Capsule', 'Itrasys 100 Capsule', 'Itrostred 200 Capsule', 'Itromed 100 Capsule', 'I-Win 100 Capsule', 'Itzhh 200 Capsule', 'Itradila 200 Capsule', 'I-Win 200 Capsule', 'Itrafix 200 Capsule', 'Itratuf Oral Solution', 'Itragreat 100 Capsule', 'Itrazole 100 Capsule', 'Itromed 200 Capsule', 'Itrason 200 Capsule', 'I-Tyza Capsule', 'Itragreat 200 Capsule', 'ITRAGEN 200MG CAPSULE', 'Itaspor Capsule', 'Itrasys CF 100 Capsule', 'Itzhh Capsule', 'Itraclar 100mg Capsule', 'Itracip 100 Capsule', 'Itragen 100 Capsule', 'Itratop 200mg Capsule', 'Itratuf Capsule', 'IT Mac 400mg Tablet SR', 'Itrasys 400 Capsule', 'Itralent 100mg Capsule', 'Itaphyte 200 Capsule', 'Itrabond 100 Capsule', 'Itralent 200 Capsule', 'Itral Eye/Ear Drops', 'Itrafix 100 Capsule', 'Itrafix 100 Capsule', 'Intrazole 200 Capsule', 'Itrabond 200 Capsule', 'Itracoe 200 Capsule', 'Itrazole 200 Capsule', 'Intawin 400 Tablet', 'Intrazole 100 Capsule', 'Itracip 200mg Capsule', 'Itraconol 200 Capsule', 'Itrostred 200 Capsule', 'Ibitra 100mg Capsule', 'Itra RD 200 Capsule', 'Itrastar 100mg Capsule', 'Itracat 200 Capsule', 'Iphytoral 100mg Capsule', 'Itrafung 100 Capsule', 'Ibitra 200mg Capsule', 'Itriben 100mg Tablet', 'Itranext Capsule', 'Itraderm DS Capsule', 'Itraclar 200 Capsule', 'Itrostred 100 Capsule', 'Itorate Capsule', 'Itracutis  100 Capsule', 'Itgo 50DT Tablet', 'Itriben 200 Capsule', 'Itracoe 400 SR Tablet', 'Itraderm Capsule', 'Itratuf Capsule', 'Itracyp 200mg Capsule', 'Itsbest 200 Capsule', 'Jimlig 100 Capsule', 'Ketocip 2% Shampoo from Cipla for Antifungal Infections', 'Ketonext Shampoo', 'Kurazol Shampoo', 'Ketosh Shampoo', 'Ketonol Shampoo', 'Klinique Shampoo', 'Ketonex Shampoo', 'Kansel-IT 200 Capsule', 'Ketoday Shampoo', 'Livafin O 200mg Capsule', 'Livafin -O 100 Capsule', 'Logispor 200 Capsule', 'leocan 150mg Tablet', 'Mycoclear 100 Capsule', 'Mitraa 200mg Capsule', 'Nuforce 150 Tablet', 'Nuforce 400mg Tablet', 'Nuforce 200 Tablet', 'Nixitral 100 Capsule', 'Nixitral 200 Capsule', 'Nizol Shampoo', 'Nokver 200 Capsule', 'Onecan 150 Tablet', 'Onitraz -Forte Capsule', 'Onitraz Capsule', 'Otodac-CL Ear Drop', 'Onecan 400 Tablet', 'Onecan 50mg Tablet', 'Odicon 150 Tablet', 'Syscan 150 Capsule', 'Syntran 200 Capsule', 'Syntran Capsule', 'Syscan 200 Capsule', 'Sporanox Capsule', 'Syntran SB Capsule', 'Surfaz-O Tablet', 'Tinitraz 200 Capsule', 'Ultican 200mg Capsule', 'Vincan Injection', 'Xerofung 200 Capsule', 'Xerofung 100 Capsule', 'Zocon 150 Tablet', 'Zocon 200 Tablet', 'Zocon 400 Tablet', 'Zocon 50 DT Tablet', 'Zitran 200 Capsule', 'Zocon 100 DT Tablet', 'Zole-IT 100 ...
# ------------------------
# Use: Treatment of Gastroesophageal reflux disease (Acid reflux)Treatment of Peptic ulcer disease
# Number of Occurrences: 175
# Medicines: ['Aciloc 150 Tablet', 'Aciloc 300 Tablet', 'Aciloc Injection', 'Acera-D Capsule SR', 'Anleo-DSR Capsule', 'Aciloc Only Oral Liquid', 'Aciban DSR Capsule', 'Athzol-DSR Capsule', 'Altapan-DSR Capsule', 'Bravia-DSR Capsule', 'Dompan SR Tablet', 'Domtac Tablet', 'Domrab  Capsule SR', 'Domtac-SR Capsule', 'Esogress-L Capsule SR', 'Esomac L Capsule SR', 'Esofag-L Capsule SR', 'Esofine-LS Capsule SR', 'EC Pan DSR Capsule', 'Esoz L Capsule SR', 'Erzol-D Capsule SR', 'Esobiz-L Capsule SR', 'Esokem-L Capsule SR', 'Ecorab D Capsule SR', 'Ecopan DSR 30 mg/20 mg Tablet', 'Gaspaz DS Capsule', 'Gaspaz Capsule', 'GR8 Capsule', 'Genpraz DSR Capsule', 'Gam-DSR Capsule', 'Happi-D Capsule SR', 'Helirab-D Capsule SR', 'Iladac DSR Capsule PR', 'Ilapro D Capsule PR', 'Izra-L Capsule SR', 'Instigo-D Tablet', 'Junior Lanzol 15mg Tablet DT', 'Junior Lanzol 30mg Tablet DT', 'Lanzol 30 Capsule', 'LAN 30 Capsule', 'Lupila-D Capsule', 'Loreb-DSR Capsule', 'Mac-RD Capsule SR', 'Minirab-D Capsule SR', 'Nexpro L Capsule ER', 'Nicopenta DSR Capsule', 'Nuloc-D Capsule SR', 'Nexarid-DSR Capsule', 'Omez-Dsr Capsule', 'Omee-D Capsule', 'Ocid-D Capsule', 'Ocid L Capsule PR', 'Omesec-RD Capsule', 'Omiflux Capsule', 'Okacid D Capsule', 'Omezax-D Capsule', 'Pan-D Capsule PR', 'Pantocid DSR Capsule', 'Pantop-D SR Capsule', 'Pantosec D SR Capsule', 'Pantop-D Capsule', 'Pantakind-DSR Capsule', 'Pantosec-D Tablet', 'Pantodac DSR Capsule', 'Pantocid D Capsule', 'Protera D Capsule', 'Parit D Capsule SR', 'Pentaloc DSR 30mg/40mg Capsule', 'Pansec DSR Capsule', 'Pantafol DSR 30mg/40mg Capsule PR', 'Pentopan DSR Capsule PR', 'Pepcia-D Capsule SR', 'Pantium DSR Capsule', 'Peptard-D Capsule SR', 'Pantin D Capsule PR', 'Piltop-DSR Capsule', 'Protochek DSR Capsule', 'P2i-D Capsule PR', 'Pantotab DSR Capsule', 'Pentab-D Tablet', 'Panum-DSR Capsule', 'Pansalve-DSR Capsule', 'Panto-DSR Capsule', 'Pantadom-SR Capsule', 'Padup Capsule PR', 'Pentaloc D 10mg/20mg Tablet', 'Pentate-D Tablet', 'Piza-D Tablet', 'Pancicare-D Capsule PR', 'Pantofix D Capsule PR', 'Pantin RD 10mg/20mg Tablet', 'PP Set DSR Capsule', 'Panido-D Tablet', 'Pptroy D Capsule PR', 'Pansa-D Tablet', 'Prazo-DSR Capsule', 'Pentowok D Tablet', 'Pantapar-DSR Capsule', 'Pansa DSR Capsule', 'Pantex-D SR Capsule', 'Pop DSR Capsule', 'Pantotas D 10mg/40mg Tablet', 'Pilpan-D Tablet', 'Praztac-D Capsule SR', 'Pantosun-DSR Capsule', 'Pantodell DSR Capsule', 'Rantac 150 Tablet', 'Razo-D Capsule SR', 'Rabekind-DSR Capsule', 'Rantac Syrup Mint', 'Rabesec-D SR Capsule', 'Rabium-DSR Capsule', 'Rebez DSR Capsule', 'Rekool D Capsule SR', 'Rantop Syrup Mango', 'Rzole DSR Capsule', 'Rabalkem-DSR Capsule', 'Rabezol DSR  Capsule', 'Rantac Injection 2ml', 'Rantac Infant Syrup Mint', 'Rantac 300 Tablet', 'Rebozen-DSR Capsule', 'Rablet D 40 Capsule SR', 'R-Loc 150 Tablet', 'Rantac OD 300 Tablet CR', 'Rbson D Capsule SR', 'Rabicip D  Capsule SR', 'Rabonik DSR Capsule', 'Rabez D 30 mg/20 mg Capsule', 'Rapeed D  Capsule SR', 'Roles-D Capsule SR', 'Rabicer DSR 30mg/20mg Capsule', 'Rabeloc RD Capsule', 'Raciper Plus Capsule SR', 'R-Loc D 10mg/150mg Tablet', 'Rabifast-DSR Capsule', 'Rabiros D Capsule SR', 'Ropraz-D SR Capsule', 'Rekool 40-D Capsule SR', 'Rafron DSR Capsule', 'Rabitec-D SR Capsule', 'RabiPlus-D Capsule PR', 'Renvorab-DSR Capsule', 'Rabcita DSR Capsule', 'Rabitop-D Capsule SR', 'Random-DSR Capsule', 'Rabex DSR Capsule', 'Rabee-D  Capsule SR', 'Rabsig-DSR Capsule', 'Rabonik 40 DSR Capsule', 'Rabidoc-D Tablet', 'Ranitin 300 Tablet', 'Raptac-DSR Capsule', 'Rebozen-D 10mg/20mg Tablet', 'Rantac Injection 2ml', 'Raciper-L Capsule PR', 'Raz Plus Tablet', 'Rostrum-D Capsule', 'Rabe-Max DSR Capsule', 'Rabezox-D Capsule SR', 'Sompraz L Capsule SR', 'Superia DSR Capsule', 'Sonirab-DSR Capsule', 'Sonirab-D Tablet', 'Steadpan-DSR Capsule', 'Snigzole D 30mg/40mg Capsule', 'Topp D Capsule', 'Ulpan-DSR Capsule', 'Ulpan-D Tablet', 'Ulphix D Capsule', 'Veloz D Capsule SR', 'Wokride-D Capsule SR', 'Waypra-D Capsule SR', 'Zipant-DSR Capsule',  ...
# ------------------------
# Use:  Fungal skin infections
# Number of Occurrences: 141
# Medicines: ['Arcolane 2% Scalp Solution', 'Amfy Gel', 'Af-ter Lotion', 'Acvaketo Soap', 'Amfy Gel', 'Af-ter Cream', 'Biospor 1% Cream', 'Dersil-AF Body Wash', 'Denon Soap', 'Dphyte Cream', 'Dany Cream', 'Esava Cream', 'Erbimesh Cream', 'Fungizole Cream', 'Fonafirst 1% Cream', 'Fungotek Cream', 'Fintrix Cream', 'Fuket Soap', 'Fintrix Cream', 'Finlite Cream', 'Gris ODT Cream', 'Iycotic Cream', 'IZ K Soap', 'Joyneca Anti fungal Soap', 'Ketostar Cream', 'Keto Cream', 'Ketofly Soap from Leeford for Skin Infections', 'K20 Soap', 'Kevon Lotion', 'Kevon Lotion', 'Kenozole Cream', 'Keto Soap', 'Konaz Antifungal Cream', 'Kenz Soap', 'Keto Gold Soap', 'KZ-XL Cream', 'Kenz Lotion', 'KZ Dusting Powder', 'K20 Cream', 'Keto Dusting Powder', 'K2-Zole Soap', 'K2-Zole Solution', 'Ketovate Cream', 'Ketafung Cream', 'Keto Cream', 'Keto Lotion', 'Ketafung Lotion', 'Kevon Cream', 'Ketzz 2% Cream', 'Ketobact Cream', 'Ketofine Cream', 'Ketofast Soap', 'Kozol Lotion', 'Ketonext AF Lotion', 'Kitnor Soap', 'Ktc 2% Cream', 'Ketonext Cream', 'Ketomed Plus Soap', 'Ketoliz 2% Cream', 'K Shine Lotion', 'Ketonext Soap', 'Ketox Cream', 'Ketogold Medicated Soap', 'Ketral  2% Scalp Solution', 'Ketoberg Soap', 'Ketofine Soap', 'K Terbimax Cream', 'Ketovate Soap', 'Ketotek Soap', 'Ketopan Soap', 'Ketzi Cream', 'Kozol Soap', 'K2-Zole LD Solution', 'Keyzol Cream', 'Ketodust Soap', 'Ketodust Cream', 'Ketoya 2% Cream', 'Ketonite Cream', 'Keyzol Soap', 'Kezop Soap', 'Lamifin Cream', 'Lamifin Lotion', 'Lamifin Lotion', 'Lamifin Dusting Powder', 'Lamifin Cream', 'Myket Cream', 'Monokit Cream', 'Mesoketz Soap', 'Mesoketz Cream', 'Nizral 2% Solution', 'Nizral Cream', 'Novale Bar', 'Nizral Cream', 'Niofine Dusting Powder', 'Nizoclin-SX Lotion', 'Nizoclin Soap', 'Novale Scalp Lotion', 'Naftate Cream', 'Nozal Soap', 'Nizoclin Cream', 'Oxicojen Cream', 'Oxicojen Lotion', 'Oxicojen Cream', 'Ocona  Soap', 'Phytoral Ointment', 'Phytoral Dusting Powder', 'Pilzban Cream', 'Pilzban Cream', 'Phytoral-XL Cream', 'Protek  Soap', 'PH-Bar', 'Sebifin Cream', 'Salisia KT Soap', 'SGK Cream', 'Sebandro Soap', 'Terbinaforce Cream', 'Terbest Cream', 'Terbicip Cream', 'Terbest Cream', 'Tyza Cream', 'Trfy Cream', 'Tyza Dusting Powder', 'Terbinaforce Dusting Powder', 'Tyza Cream', 'Texifen Cream', 'Terbicip Spray', 'Tebina Cream', 'Terefin Cream', 'Terbiderm Cream', 'Terbest Dusting Powder', 'Terbison Cream', 'Terfin Cream', 'Terbiface Cream', 'Terbicrat Cream', 'Terbifast 1% Cream', 'Terfin Dusting Powder', 'Terbee Cream', 'Zoderm E Cream', 'Zimig 1% Cream', 'ZyKT Cream', 'ZyKT Cream']
# ------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'clean_df' contains the necessary data

# Get the value counts of side effects and limit to top 10
side_effects_counts = clean_df['Side_effects'].value_counts().head(10)

# Create a dictionary to store medicines for each side effect
side_effects_medicines = {}

# Loop through unique side effects and collect associated medicines
for side_effect in side_effects_counts.index:
    # Filter DataFrame for each unique side effect
    medicines_for_side_effect = clean_df.loc[clean_df['Side_effects'] == side_effect, 'Medicine Name'].tolist()

    # Store the list of medicines for the side effect in the dictionary
    side_effects_medicines[side_effect] = medicines_for_side_effect

# Create a bar chart of top 10 side effects and their counts with improved aesthetics
plt.figure(figsize=(12, 8))
bar_plot = side_effects_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Adding annotations for each bar with custom formatting
for i, count in enumerate(side_effects_counts):
    plt.text(i, count + 1, f'{count}', ha='center', va='bottom', fontsize=10)

# Draw a horizontal line for the mean count
mean_count = side_effects_counts.mean()
plt.axhline(mean_count, color='red', linestyle='--', label=f'Mean: {mean_count:.2f}')
plt.legend()

# Draw a horizontal line for the median count
median_count = side_effects_counts.median()
plt.axhline(median_count, color='green', linestyle="--", label=f'Median: {median_count:.2f}')
plt.legend()

plt.title('Top 10 Occurrences of Side Effects')
plt.xlabel('Side Effects')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-d164a2bf809f>:43: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
top_10_uses = uses_counts.head(10)

# Calculate median and mean values
median_value = top_10_uses.median()
mean_value = top_10_uses.mean()

# Create a bar chart for top 10 uses and their occurrences
plt.figure(figsize=(13, 10))
bar_plot = top_10_uses.plot(kind='bar', color='skyblue', edgecolor='black')

# Adding annotations for each bar
for i, count in enumerate(top_10_uses):
    plt.text(i, count + 1, str(count), ha='center', va='bottom', fontsize=10)

# Plotting median line with annotation
plt.axhline(median_value, color='red', linestyle='--', linewidth=1.5, label=f'Median: {median_value:.2f}')
plt.text(len(top_10_uses) - 1, median_value, f'Median: {median_value:.2f}', color='red', va='bottom', ha='right', fontsize=10)

# Plotting mean line with annotation
plt.axhline(mean_value, color='green', linestyle='-.', linewidth=1.5, label=f'Mean: {mean_value:.2f}')
plt.text(len(top_10_uses) - 1, mean_value, f'Mean: {mean_value:.2f}', color='green', va='bottom', ha='right', fontsize=10)

plt.title('Top 10 Occurrences of Uses and Associated Medicines', fontsize=14)
plt.xlabel('Uses', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(0, top_10_uses.max() * 1.1)
plt.legend(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Vectorize each column separately
tfidf_vectorizer_uses = TfidfVectorizer(stop_words='english')
tfidf_matrix_uses = tfidf_vectorizer_uses.fit_transform(clean_df['Uses'].astype(str))

tfidf_vectorizer_composition = TfidfVectorizer(stop_words='english')
tfidf_matrix_composition = tfidf_vectorizer_composition.fit_transform(clean_df['Composition'].astype(str))

tfidf_vectorizer_side_effects = TfidfVectorizer(stop_words='english')
tfidf_matrix_side_effects = tfidf_vectorizer_side_effects.fit_transform(clean_df['Side_effects'].astype(str))

# %%
# Ensure all matrices have the same number of rows
min_rows = min(tfidf_matrix_uses.shape[0], tfidf_matrix_composition.shape[0], tfidf_matrix_side_effects.shape[0])

# %%
# Trim matrices to have the same number of rows
tfidf_matrix_uses = tfidf_matrix_uses[:min_rows]
tfidf_matrix_composition = tfidf_matrix_composition[:min_rows]
tfidf_matrix_side_effects = tfidf_matrix_side_effects[:min_rows]

# %%
# Combine the matrices horizontally
tfidf_matrix_combined = hstack((tfidf_matrix_uses, tfidf_matrix_composition, tfidf_matrix_side_effects))

# %%
# Save necessary components for inference
with open('recommend.pkl', 'wb') as file:
    pickle.dump({
        'tfidf_vectorizer_uses': tfidf_vectorizer_uses,
        'tfidf_matrix_uses': tfidf_matrix_uses,
        'clean_df': clean_df
    }, file)

# %%
# Function to recommend medicines based on symptoms
def recommend_medicines_by_symptoms(symptoms, tfidf_vectorizer, tfidf_matrix_uses, clean_df):
    # Create a string from the given symptoms
    symptom_str = ' '.join(symptoms)

    # Transform the symptom string using the TF-IDF vectorizer
    symptom_vector = tfidf_vectorizer.transform([symptom_str])

    # Calculate cosine similarity between the symptom vector and all medicine vectors
    sim_scores = cosine_similarity(tfidf_matrix_uses, symptom_vector)

    # Get indices of top similar medicines
    sim_scores = sim_scores.flatten()
    similar_indices = sim_scores.argsort()[::-1][:5]  # Top 5 similar medicines

    # Get recommended medicine names
    recommended_medicines = clean_df.iloc[similar_indices]['Medicine Name'].tolist()

    return recommended_medicines
